# %% [markdown]
# # PREPARE DATA
#
# The *main_figures.ipynb* and *supp_figures.ipynb* notebooks generate all plots in the manuscript, but in order to do so they make use of supplementary files that are generated by running this notebook (this may take some time).

# %%
from functions import *

# %% [markdown]
# # PREPARE DATASET
# First we need to download the ATLAS dataset (https://amr.theodi.org/programmes/atlas) from the following URL:
# https://s3-eu-west-1.amazonaws.com/amr-prototype-data/Open+Atlas_Reuse_Data.xlsx
#
# We need to play a little with the original dataset.

# %%
#WE READ THE EXCEL FILE
DF=pd.read_excel('data/Open+Atlas_Reuse_Data.xlsx', skiprows=[0, 1, 2, 3, 4]))
DF=DF.rename(columns={'In / Out Patient': 'InOutPatient'})
#WRITE DATAFRAME'S KEYS (USEFUL FOR LATER ANALYSES)
keys=['Year', 'Country', 'Species']
mkeys={}
for key in keys:
    dL=DF[key].tolist()
    mkeys[key]={}
    for i,z in enumerate(dL):
        z=str(z)
        if z not in mkeys[key]:
            mkeys[key][z]=0  
        mkeys[key][z]+=1
    with open('data/key_'+key+'.txt','w') as f:
        for z in sorted(mkeys[key], key=lambda x: (str(type(x)), x)):
            f.write(str(z)+'\t'+str(mkeys[key][z])+'\n')

#WE WANT TO LOG2-TRANSFORM THE MIC VALUES IN THE DATASET
#BUT MIC VALUES APPEAR IN A VARIETY OF WAYS THROUGHOUT THE DATASET
#FILE data/key_MIC_values.txt HOLDS ALL MIC VALUES IN THE DATASET
#IN THE FIRST COLUMN. IN THE SECOND WE HAVE MODIFIED THEM, AND IN THE
#THIRD WE HAVE THE LOG2-TRANSFORMED VALUES
MICdict=[]
with open('data/key_MIC_values.txt', 'r') as f:
    for line in f:
        w=line.split()
        k1=w[0]
        k3=float(w[2])
        MICdict.append([k1, str(k3), len(k1)])
MICdict=sorted(MICdict, key=itemgetter(2), reverse=True)

#WE ASSIGN A RANDOM KEY TO EACH MIC VALUE BEFORE SUBSTITUTING
import string
import random
def randomString(stringLength=10):
    """Generate a random string of fixed length """
    letters = string.ascii_lowercase
    return ''.join(random.choice(letters) for i in range(stringLength))
eggs=[randomString() for z in MICdict]

#NOW WE SUBSTITUTE THEM IN THE DATASET
drugs=read_key('Drugs', 'data/')
for dr in drugs:
    DF[dr]=DF[dr].astype('str')
    for x1,y1 in zip(MICdict,eggs):
        DF[dr]=DF[dr].str.replace(x1[0],y1)
    for x1,y1 in zip(eggs,MICdict):
        DF[dr]=DF[dr].str.replace(x1,y1[1])
    DF[dr]=DF[dr].astype('float64')
DF['Species']=DF['Species'].astype('str')
#FINALLY, WE UNIFORMIZE SOME SPECIES
DF['Species']=DF['Species'].str.replace('Enterobacter aerogenes', 'Klebsiella aerogenes', regex=False)
DF['Species']=DF['Species'].str.replace('Klebsiella (Enterobacter) aerogenes', 'Klebsiella aerogenes', regex=False)
DF['Species']=DF['Species'].str.replace('Klebsiella planticola', 'Raoultella planticola', regex=False)
DF.to_excel('data/atlas.xlsx')   
#WRITE NEW SPECIES FILE
mkeys={}
dL=DF['Species'].tolist()
for i,z in enumerate(dL):
    z=str(z)
    if z not in mkeys:
        mkeys[z]=0  
    mkeys[z]+=1
with open('data/key_Species.txt','w') as f:
    for z in sorted(mkeys, key=lambda x: (str(type(x)), x)):
        f.write(str(z)+'\t'+str(mkeys[z])+'\n')

# %% [markdown]
# # DATABASES
#
# The ATLAS program is the amalgamation of two previous antimicrobial surveillance programs: TEST (2004-2017) and INFORM (2012-2017). Here we separate these two in order to assess the consistency of our results (run this cell immediately after running the previous one).

# %%
DFT=DF[DF.Study=='TEST']
DFT.to_excel('data/test.xlsx')
DFI=DF[DF.Study=='Inform']
DFI.to_excel('data/inform.xlsx')
DF2012=DF[DF.Year>2011]
DF2012.to_excel('data/atlas2012.xlsx')
#COUNTRIES DATABASES
DFA=DF[DF.Country=='United States']
DFA.to_excel('data/atlas_usa.xlsx')
RD=pd.read_csv('data/europe_resistance_data.csv')
Europe=get_key(RD, 'Country')#GET LIST OF EUROPEAN COUNTRIES FROM ECDC DATA
for i,c in enumerate(Europe):
    if c=='Slovakia':
        Europe[i]='Slovak Republic'
DFE=DF[DF.Country.isin(Europe)]
DFE.to_excel('data/atlas_europe.xlsx')
West=['United States']+Europe
DFR=DF[~DF.Country.isin(West)]
DFR.to_excel('data/atlas_rest.xlsx')

# %% [markdown]
# # DATAPOINTS PER YEAR
# Datafile to represent how many species and datapoints are recorded each year in ATLAS (Fig S1D).

# %%
DF=pd.read_excel('data/atlas.xlsx')
yL=list(range(2004,2018))
spL=[]
dataL=[]
for year in yL:
    DFy=DF[DF.Year==year]
    k1=get_key(DFy,'Species')
    dataL.append(len(DFy))
    spL.append(len(k1))
DFnew=pd.DataFrame({'Year':yL, 'Species': spL, 'Datapoints': dataL})
DFnew.to_csv('data/datapoints_per_year.csv', index=False)

# %% [markdown]
# # READ DATASET
# Useful for later cells.

# %%
DF, pL, bP, drugs=read_dataset('atlas', complete=True)#READS ALL OF ATLAS

# %%
DF, pL, bP, drugs=read_dataset('atlas')#READS ONLY THE RESTRICTED VERSION OF ATLAS THAT WE USED FOR THE PAPER

# %%
DF, pL, bP, drugs=read_dataset('test')#READS TEST ONLY

# %%
DF, pL, bP, drugs=read_dataset('inform')#READS INFORM ONLY

# %% [markdown]
# # AVERAGE MIC PER YEAR
# Datafile to represent average MIC for each country (Figs 4A, 4C).

# %%
DF, pL, bP, drugs=read_dataset('atlas')
L=[]
pC=get_key(DF,'Country')
for country in pC:#for every country
    DFc=DF[DF.Country==country]
    if DFc.empty: continue   
    for sp in pL:#for every pathogen
        DFsp=DFc[DFc.Species==sp]
        if DFsp.empty: continue
        for dr in drugs:#for every drug
            if dr not in bP[sp]: continue
            DFnew=pd.DataFrame({'Year': DFsp['Year'], dr: DFsp[dr]})
            DFnew=DFnew.dropna()
            if DFnew.empty: continue
            yL=get_key(DFnew, 'Year')
            for y in yL:#for every year
                DFy=DFnew[DFnew.Year==y]
                if DFy.empty: continue
                #DATA
                rcases=DFy[DFy[dr]>bP[sp][dr][0]].count()[dr]  
                m=DFy[dr].mean()-bP[sp][dr][0]
                merr=DFy[dr].sem()
                mstd=DFy[dr].std()
                N=len(DFy)
                R=rcases
                F=rcases/N
                #RECORD
                L.append([sp,dr,country,y,m,merr,mstd,N,R,F])
#SAVE ALL IN DATAFRAME AND WRITE TO FILE
MICdf=pd.DataFrame.from_records(L, columns=['Species', 'Antibiotic', 'Country', 'Year', 'Average MIC', 'Average MIC SEM', 'Average MIC SD', 'Number of cases', 'Number of resistant cases', 'Fraction of resistant cases'])
MICdf.to_csv('data/average_mic_per_year.csv', float_format='%.3f', na_rep='NaN', index=False)

# %% [markdown]
# # COMPARE DATASETS
# Compare resistance values in ATLAS against ECDC and ResistanceMap (Fig 1A,Supp Figs 2 and 3).

# %% [markdown]
# ## ATLAS VS ECDC

# %%
#READ AVERAGE MIC DATA
DFavg=pd.read_csv('data/average_mic_per_year.csv')
#READ ECDC DATA
RD=pd.read_csv('data/europe_resistance_data.csv')
#we want to compare fraction of resistance in both datasets
RD=RD[RD.Indicator=='Nonsusceptible proportion']
RD['Year']=RD['Year'].astype('int64')
RD['Value']=RD['Value'].astype('float64')
spR=get_key(RD, 'Species')
cR=get_key(RD, 'Country')
dR=get_key(RD, 'Antibiotic')
#ECDC resistance data comes aggregated for drug classes and for different
#pathogens. For instance, for Acinetobacter it reports resistance to
#'Carbapenems'. We therefore compare with resistance to all drugs tested
#in ATLAS for that pathogen-drug class combination, as specified in the
#ECDC website.
#Also, Acinetobacter is reported as a genus, but we here only compare with
#A.baumannii, which is by far the most important pathogen
RD['Species']=RD['Species'].str.replace('Acinetobacter spp.', 'Acinetobacter baumannii')
Rant={}
Rant['Acinetobacter baumannii']={'Carbapenems':['Imipenem', 'Meropenem']}
Rant['Enterococcus faecalis']={'Highlevel gentamicin':['Gentamicin'],
    'Vancomycin':['Vancomycin']}
Rant['Enterococcus faecium']={'Highlevel gentamicin':['Gentamicin'],
    'Vancomycin':['Vancomycin']}
Rant['Escherichia coli']={'Carbapenems':['Imipenem', 'Meropenem']}
Rant['Klebsiella pneumoniae']={'Carbapenems':['Imipenem, Meropenem']}
Rant['Pseudomonas aeruginosa']={'Carbapenems':['Imipenem', 'Meropenem'],
    'Ceftazidime':['Ceftazidime'],
    'PiperacillinTazobactam':['Piperacillin tazobactam']}
Rant['Staphylococcus aureus']={'Meticillin (MRSA)':['Oxacillin']}
Rant['Streptococcus pneumoniae']={'Macrolides':['Erythromycin', 'Clarithromycin', 'Azithromycin'],
    'Penicillins': ['Penicillin', 'Oxacillin']}

#COMPARE RESISTANCE RATES
yL=list(range(2004,2018))
L=[]
for sp, country in itertools.product(spR, cR):
    DFsp=DFavg[(DFavg.Species==sp) & (DFavg.Country==country)]
    RDsp=RD[(RD.Species==sp) & (RD.Country==country)]
    if DFsp.empty or RDsp.empty: continue
    for key,value in Rant[sp].items():
        DFc=DFsp[DFsp.Antibiotic.isin(value)]
        RDc=RDsp[RDsp.Antibiotic==key]
        for y in yL:
            DFy=DFc[DFc.Year==y]
            RDy=RDc[RDc.Year==y]
            if DFy.empty or RDy.empty: continue
            x1=RDy.Value.mean()
            if np.isnan(x1): continue
            y1=DFy['Fraction of resistant cases'].mean()*100
            diff=y1-x1
            N=DFy['Number of cases'].sum()
            L.append([sp,key,y,country,x1,y1,diff,N])
NewDF=pd.DataFrame.from_records(L, columns=['Species','Antibiotic','Year','Country','ECDCValue','ATLASValue','Diff','N'])
NewDF.to_excel('data/atlas_vs_ecdc.xls', float_format='%.3f', index=False)

# %% [markdown]
# ## ATLAS VS RESISTANCEMAP

# %%
#READ AVERAGE MIC DATA
DFavg=pd.read_csv('data/average_mic_per_year.csv')
#READ RESISTANCEMAP DATA
RD=pd.read_csv('data/resistmap_data.csv')
RD['year']=RD['year'].astype('int64')
RD['value']=RD['value'].astype('float64')
RD['IsolatesTested']=RD['IsolatesTested'].astype('float64')
spR=get_key(RD, 'Organism')
cR=get_key(RD, 'CountryName')
dR=get_key(RD, 'Antimicrobial')
#DATA IN RESISTANCEMAP IS AGGREGATED IN A SIMILAR WAY AS IN ECDC
Rant={}
Rant['Acinetobacter baumannii']={'Amikacin':['Amikacin'], 
    'Ampicillin-sulbactam':['Ampicillin sulbactam'],
    'Carbapenems':['Imipenem', 'Meropenem'],
    'Ceftazidime':['Ceftazidime'],
    'Glycylcyclines':['Tigecycline']}
Rant['Enterobacter aerogenes/cloacae']={'Amoxicillin-clavulanate':['Amoxicillin clavulanate'],
    'Carbapenems':['Imipenem', 'Meropenem'],
    'Glycylcyclines':['Tigecycline'],
    'Piperacillin-tazobactam':['Piperacillin tazobactam']}
Rant['Enterococcus faecalis']={'Aminoglycosides (high-level)':['Gentamicin'],
    'Vancomycin':['Vancomycin']}
Rant['Enterococcus faecium']={'Vancomycin':['Vancomycin']}
Rant['Escherichia coli']={'Amoxicillin-clavulanate':['Amoxicillin clavulanate'],
    'Carbapenems':['Imipenem', 'Meropenem'],
    'Glycylcyclines':['Tigecycline'],
    'Piperacillin-tazobactam':['Piperacillin tazobactam']}
Rant['Klebsiella pneumoniae']={'Amoxicillin-clavulanate':['Amoxicillin clavulanate'],
    'Carbapenems':['Imipenem, Meropenem'],
    'Glycylcyclines':['Tigecycline'],
    'Piperacillin-tazobactam':['Piperacillin tazobactam']}
Rant['Pseudomonas aeruginosa']={'Amikacin':['Amikacin'],
    'Carbapenems':['Imipenem', 'Meropenem'],
    'Ceftazidime':['Ceftazidime'],
    'Piperacillin-tazobactam':['Piperacillin tazobactam']}
Rant['Staphylococcus aureus']={'Linezolid':['Linezolid'],
    'Oxacillin (MRSA)':['Oxacillin'],
    'Vancomycin':['Vancomycin']}
Rant['Streptococcus pneumoniae']={'Macrolides':['Erythromycin', 'Clarithromycin', 'Azithromycin']}

#COMPARE RESISTANCE RATES
yL=list(range(2004,2018))
L=[]
for sp, country in itertools.product(spR, cR):
    DFsp=DFavg[(DFavg.Species==sp) & (DFavg.Country==country)]
    RDsp=RD[(RD.Organism==sp) & (RD.CountryName==country)]
    if DFsp.empty or RDsp.empty: continue
    for key,value in Rant[sp].items():
        DFc=DFsp[DFsp.Antibiotic.isin(value)]
        RDc=RDsp[RDsp.Antimicrobial==key]
        for y in yL:
            DFy=DFc[DFc.Year==y]
            RDy=RDc[RDc.year==y]
            if DFy.empty or RDy.empty: continue
            x1=RDy.value.mean()
            xhigh=RDy.CIHigh.mean()
            xlow=RDy.CILow.mean()
            if np.isnan(x1): continue
            y1=DFy['Fraction of resistant cases'].mean()*100
            diff=y1-x1
            N=DFy['Number of cases'].sum()
            L.append([sp,key,y,country,x1,xhigh,xlow,y1,diff,N])

NewDF=pd.DataFrame.from_records(L, columns=['Species','Antibiotic','Year','Country','RMapValue','RMapCIHigh', 'RMapCILow','ATLASValue','Diff','N'])
NewDF.to_excel('data/atlas_vs_resistancemap.xls', float_format='%.3f', index=False)

# %% [markdown]
# ## ATLAS VS ESPAUR

# %%
#READ AVERAGE MIC DATA
DFavg=pd.read_csv('data/average_mic_per_year.csv')
#READ RESISTANCEMAP DATA
RD=pd.read_excel('data/espaur.xlsx', engine='openpyxl')
RD['Year']=RD['Year'].astype('int64')
RD['Value']=RD['Value'].astype('float64')
spR=get_key(RD, 'Species')
dR=get_key(RD, 'Antimicrobial')
#DATA IN RESISTANCEMAP IS AGGREGATED IN A SIMILAR WAY AS IN ECDC
Rant={}
Rant['Acinetobacter']={'Colistin':['Colistin']}
Rant['Enterococcus']={'Vancomycin':['Vancomycin']}
Rant['Escherichia coli']={'Ciprofloxacin': ['Levofloxacin'],
    'Gentamicin': ['Gentamicin'], 
    'Cephalosporins':['Ceftazidime', 'Ceftriaxone'],
    'Carbapenems':['Imipenem', 'Meropenem'],
    'Co-amoxiclav': ['Amoxicillin clavulanate'],
    'Piperacillin-Tazobactam':['Piperacillin tazobactam']}
Rant['Klebsiella pneumoniae']={'Ciprofloxacin': ['Levofloxacin'],
    'Gentamicin': ['Gentamicin'], 
    'Cephalosporins':['Ceftazidime', 'Ceftriaxone'],
    'Carbapenems':['Imipenem', 'Meropenem'],
    'Co-amoxiclav': ['Amoxicillin clavulanate'],
    'Piperacillin-Tazobactam':['Piperacillin tazobactam']}
Rant['Klebsiella oxytoca']={'Ciprofloxacin': ['Levofloxacin'],
    'Gentamicin': ['Gentamicin'], 
    'Cephalosporins':['Ceftazidime', 'Ceftriaxone'],
    'Carbapenems':['Imipenem', 'Meropenem'],
    'Co-amoxiclav': ['Amoxicillin clavulanate'],
    'Piperacillin-Tazobactam':['Piperacillin tazobactam']}
Rant['Pseudomonas aeruginosa']={'Ciprofloxacin': ['Levofloxacin'],
    'Gentamicin': ['Gentamicin'], 
    'Carbapenems':['Imipenem', 'Meropenem'],
    'Ceftazidime':['Ceftazidime'],
    'Piperacillin-Tazobactam':['Piperacillin tazobactam']}
Rant['Streptococcus pneumoniae']={'Macrolides':['Erythromycin', 'Clarithromycin', 'Azithromycin'],
    'Penicillin': ['Penicillin']}

#COMPARE RESISTANCE RATES
yL=list(range(2011,2018))
L=[]
for sp in spR:
    DFsp=DFavg[(DFavg.Species.str.contains(sp)) & (DFavg.Country=='United Kingdom')]
    RDsp=RD[RD.Species==sp]
    if DFsp.empty or RDsp.empty: continue
    for key,value in Rant[sp].items():
        DFc=DFsp[DFsp.Antibiotic.isin(value)]
        RDc=RDsp[RDsp.Antimicrobial==key]
        for y in yL:
            DFy=DFc[DFc.Year==y]
            RDy=RDc[RDc.Year==y]
            if DFy.empty or RDy.empty: continue
            x1=RDy.Value.mean()
            if np.isnan(x1): continue
            y1=DFy['Fraction of resistant cases'].mean()*100
            diff=y1-x1
            N=DFy['Number of cases'].sum()
            L.append([sp,key,y,x1,y1,diff,N])

NewDF=pd.DataFrame.from_records(L, columns=['Species','Antibiotic','Year','ESPAURValue','ATLASValue','Diff','N'])
NewDF.to_excel('data/atlas_vs_espaur.xls', float_format='%.3f', index=False)

# %% [markdown]
# # ATLAS QUALITY
# Datafiles to represent correlelograms (Figs 1B, 1C, 1D, 3, 7, Supp Figs 8A, 8B, 9, 10, 12, 22)

# %%
#CREATE NEW DIRECTORY
import os
try:
    os.mkdir('results/')
except OSError as error:
    print('results folder already created')
try:
    os.mkdir('results/correlations')
except OSError as error:
    print('correlations folder already created')

DF, pL, bP, drugs=read_dataset('atlas')
#COMPUTE CORRELATIONS BETWEEN YEARS FOR EACH PA
bins=np.arange(-10.5,11.5,1)
z=np.zeros(len(bins))
for sp,dr in itertools.product(pL,drugs):
    DFsp=DF[DF.Species==sp]
    DFc=pd.DataFrame({'Year': DFsp['Year'], dr: DFsp[dr]})
    DFc=DFc.dropna()
    if DFc.empty: continue
    Y=get_key(DFc,'Year')
    H=[z for Y in Y]#H will hold the distribution of MIC values each year
    for i1,y in enumerate(Y):
        DFy=DFc[DFc.Year==y]
        h,b1=np.histogram(DFy[dr], bins=bins, density=True)
        H[i1]=h
    H=np.array(H)
    R=np.corrcoef(H)#correlation between the MIC distributions in different years
    if R.size>1:
        np.savetxt('results/correlations/'+sp+'_'+dr+'.txt',R,fmt='%.3f')
        np.savetxt('results/correlations/'+sp+'_'+dr+'_years.txt',Y, fmt='%d')
#COMPUTE TAU FOR EVERY PA PAIR  
from os import path
Dl=[]
for sp,dr in itertools.product(pL,drugs):
    if path.exists('results/correlations/'+sp+'_'+dr+'.txt'):
        R,Y=read_corr(sp, dr)
        n,m=R.shape
        tau,tauN=tautest(R)
        Dl.append([sp,dr,tau,tauN,n])     
Dl=sorted(Dl, reverse=True, key=itemgetter(2))
DFdist=pd.DataFrame.from_records(Dl, columns=['Species', 'Antibiotic', 'Tau', 'TauN', 'N'])
DFdist.to_csv('results/correlations/tau_test.csv', float_format='%.3f', index=False)

# %% [markdown]
# # TEST QUALITY

# %%
#CREATE NEW DIRECTORY
import os
import os
try:
    os.mkdir('results_test/')
except OSError as error: 
    print('results_test folder already created')
try:
    os.mkdir('results_test/correlations')
except OSError as error: 
    print('results_test/correlations already created')

DF, pL, bP, drugs=read_dataset('test')
#COMPUTE CORRELATIONS BETWEEN YEARS FOR EACH PA
bins=np.arange(-10.5,11.5,1)
z=np.zeros(len(bins))
for sp,dr in itertools.product(pL,drugs):
    DFsp=DF[DF.Species==sp]
    DFc=pd.DataFrame({'Year': DFsp['Year'], dr: DFsp[dr]})
    DFc=DFc.dropna()
    if DFc.empty: continue
    Y=get_key(DFc,'Year')
    H=[z for Y in Y]#H will hold the distribution of MIC values each year
    for i1,y in enumerate(Y):
        DFy=DFc[DFc.Year==y]
        h,b1=np.histogram(DFy[dr], bins=bins, density=True)
        H[i1]=h
    H=np.array(H)
    R=np.corrcoef(H)#correlation between the MIC distributions in different years
    if R.size>1:
        np.savetxt('results_test/correlations/'+sp+'_'+dr+'.txt',R,fmt='%.3f')
        np.savetxt('results_test/correlations/'+sp+'_'+dr+'_years.txt',Y, fmt='%d')

# %% [markdown]
# # INFORM QUALITY

# %%
#CREATE NEW DIRECTORY
import os
try:
    os.mkdir('results_inform/')
except OSError as error: 
    print('results_inform folder already created')
try:
    os.mkdir('results_inform/correlations')
except OSError as error: 
    print('results_inform/correlations already created')

DF, pL, bP, drugs=read_dataset('inform')
#COMPUTE CORRELATIONS BETWEEN YEARS FOR EACH PA
bins=np.arange(-10.5,11.5,1)
z=np.zeros(len(bins))
for sp,dr in itertools.product(pL,drugs):
    DFsp=DF[DF.Species==sp]
    DFc=pd.DataFrame({'Year': DFsp['Year'], dr: DFsp[dr]})
    DFc=DFc.dropna()
    if DFc.empty: continue
    Y=get_key(DFc,'Year')
    H=[z for Y in Y]#H will hold the distribution of MIC values each year
    for i1,y in enumerate(Y):
        DFy=DFc[DFc.Year==y]
        h,b1=np.histogram(DFy[dr], bins=bins, density=True)
        H[i1]=h
    H=np.array(H)
    R=np.corrcoef(H)#correlation between the MIC distributions in different years
    if R.size>1:
        np.savetxt('results_inform/correlations/'+sp+'_'+dr+'.txt',R,fmt='%.3f')
        np.savetxt('results_inform/correlations/'+sp+'_'+dr+'_years.txt',Y, fmt='%d')

# %% [markdown]
# # TEST/INFORM CONSISTENCY
# Check if both databases are consistent

# %%
#DF, pL, bP, drugs=read_dataset('atlas')
DFT, pLT, bPT, drugsT=read_dataset('test')
DFI, pLI, bPI, drugsI=read_dataset('inform')
#COMPUTE CORRELATIONS BETWEEN YEARS FOR EACH PA
bins=np.arange(-10.5,11.5,1)
z=np.zeros(len(bins))
for sp,dr in itertools.product(pL,drugs):
    DFTsp=DFT[DFT.Species==sp]
    DFIsp=DFI[DFI.Species==sp]
    DFTc=pd.DataFrame({'Year': DFTsp['Year'], dr: DFTsp[dr]})
    DFTc=DFTc.dropna()
    DFIc=pd.DataFrame({'Year': DFIsp['Year'], dr: DFIsp[dr]})
    DFIc=DFIc.dropna()
    if DFTc.empty or DFIc.empty: continue
    YT=get_key(DFTc,'Year')
    YI=get_key(DFIc,'Year')
    Y=[]
    for y in YT:
        if y in YI:
            Y.append(y)
    for y in YI:
        if y in YT and y not in Y:
            Y.append(y)
    Y=sorted(Y)
    print(sp,dr,Y)
    if not Y: continue
    HT=[z for _ in Y]#H will hold the distribution of MIC values each year
    HI=[z for _ in Y]#H will hold the distribution of MIC values each year
    for i1,y in enumerate(Y):
        DFTy=DFTc[DFTc.Year==y]
        h,b1=np.histogram(DFTy[dr], bins=bins, density=True)
        HT[i1]=h
        DFIy=DFIc[DFIc.Year==y]
        h,b1=np.histogram(DFIy[dr], bins=bins, density=True)
        HI[i1]=h
    HT=np.array(HT)
    HI=np.array(HI)
    R=np.corrcoef(HT,HI)#correlation between the MIC distributions in different years
    if R.size>1:
        np.savetxt('results/correlations/'+sp+'_'+dr+'_test_vs_inform.txt',R,fmt='%.3f')
        np.savetxt('results/correlations/'+sp+'_'+dr+'_test_vs_inform_years.txt',Y, fmt='%d')
#COMPUTE TAU FOR EVERY PA PAIR  
from os import path
Dl=[]
for sp,dr in itertools.product(pL,drugs):
    if path.exists('results/correlations/'+sp+'_'+dr+'_test_vs_inform.txt'):
        R=[]
        with open('results/correlations/'+sp+'_'+dr+'_test_vs_inform.txt','r') as f:
            for line in f:
                R.append([float(x) for x in line.split()])
        Y=[]
        with open('results/correlations/'+sp+'_'+dr+'_test_vs_inform_years.txt','r') as f:
            for line in f:
                w=line.split()
                Y.append(int(w[0]))
        R=np.array(R)
        n,m=R.shape
        tau,tauN=tautest(R)
        Dl.append([sp,dr,tau,tauN,n])     
Dl=sorted(Dl, reverse=True, key=itemgetter(2))
DFdist=pd.DataFrame.from_records(Dl, columns=['Species', 'Antibiotic', 'Tau', 'TauN', 'N'])
DFdist.to_csv('results/correlations/tau_test_test_vs_inform.csv', float_format='%.3f', index=False)

# %% [markdown]
# # MIC CHANGE
# Data files to represent MIC change in clustermaps (Figs 4B, 5B, 8A, 8B, 8C, Supp Figs 14, 20A, 20B, 20C)

# %%
DF, pL, bP, drugs=read_dataset('atlas')
#GLOBAL MIC CHANGE (FOR CLUSTERMAPS)
L=[]
for sp, dr in itertools.product(pL, drugs):
    DFsp=DF[DF.Species==sp]
    M=mic_change(sp,dr,DFsp)
    if not M: continue
    L.append(M)
MIC=pd.DataFrame.from_records(L, columns=['Species', 'Antibiotic', 'MIC change', 'MIC change error', 'Intercept'])
#WRITE TO FILE
MIC.to_csv('data/mic_change_global.csv', na_rep='NaN', float_format='%.3f', index=False)
        
#EUROPEAN MIC CHANGE
RD=pd.read_csv('data/europe_resistance_data.csv')
#GET LIST OF EUROPEAN COUNTRIES FROM ECDC DATA
cR=get_key(RD, 'Country')
for i,c in enumerate(cR):
    if c=='Slovakia':
        cR[i]='Slovak Republic'
DFE=DF[DF.Country.isin(cR)]
for sp,dr in itertools.product(pL, drugs):
    DFsp=DFE[DFE.Species==sp]
    if not M: continue
    M=mic_change(sp,dr,DFsp)
    L.append(M)
MIC=pd.DataFrame.from_records(L, columns=['Species', 'Antibiotic', 'MIC change', 'MIC change error', 'Intercept'])
#WRITE TO FILE
MIC.to_csv('data/mic_change_europe.csv', na_rep='NaN', float_format='%.3f', index=False)

#MIC CHANGE PER COUNTRY
L=[]
pC=get_key(DF,'Country')
for sp, dr in itertools.product(pL, drugs):
    DFsp=DF[DF.Species==sp]
    for country in pC:
        DFc=DFsp[DFsp.Country==country]
        M=mic_change(sp,dr,DFc)
        if not M: continue
        L.append([country]+M)
MIC=pd.DataFrame.from_records(L, columns=['Country','Species', 'Antibiotic', 'MIC change', 'MIC change error', 'Intercept'])
#WRITE TO FILE
MIC.to_csv('data/mic_change_per_country.csv', na_rep='NaN', float_format='%.3f', index=False)

# %% [markdown]
# # MIC DISTRIBUTIONS, GAUSSIAN MIXTURE AND R CLUSTER
# Datafiles to record the MIC distributions (raw and smooth) of every PA pair for all years (oH and sH), the Gaussian Mixture fit (Z), and the R cluster. Used in Figs 1B, 1C, 3, 5A, 5D, 6C, Supp Figs 11, 12, 15, 16, 18)

# %%
#CREATE NEW DIRECTORY
import os
try:
    os.mkdir('results/mic_distributions')
except OSError as error: 
    print('mic_distributions folder already created')
try:
    os.mkdir('results/Rcluster')
except OSError as error: 
    print('Rcluster folder already created')

DF, pL, bP, drugs=read_dataset('atlas')
#GET GAUSSIAN MIXTURE FOR EACH PA PAIR
from functions import *
for sp in pL:
    for dr in drugs:
        BP=0
        if dr in bP[sp]:
            BP=bP[sp][dr][0]
            continue#because we have done it already!
        pY,pM,sM=mic_dist(sp,dr,DF,BP)
        if not pY: continue
        #GAUSSIAN MIXTURE AND R CLUSTER
        result=False
        while result==False:#sometimes the Gaussian mixture doesn't work
            try:
                extract_rcluster(sp, dr, pY, pM, sM, DF)
                Z,gmm_x=gaussian_mixture(pY, sM)
                result=True
            except:
                pass
        np.savetxt('results/mic_distributions/'+sp+'_'+dr+'.txt',Z,fmt='%.3f')                
        np.savetxt('results/mic_distributions/'+sp+'_'+dr+'_years.txt',pY, fmt='%d')
        #WRITE HISTOGRAMS
        sH=[]
        oH=[]
        for i,y in enumerate(pY):
            # Make regular histogram (SMOOTHMIC)
            B1=np.arange(-10,10.5,0.5)
            n1, bins1=np.histogram(sM[i], bins=B1, density=True)                     
            # Make regular histogram (MIC)
            B2=np.arange(-10,10.5,1)
            n2, bins2=np.histogram(pM[i], bins=B2, density=True)
            sH.append(n1)
            oH.append(n2)
        sH=np.array(sH, dtype=float)
        oH=np.array(oH, dtype=float)
        np.savetxt('results/mic_distributions/'+sp+'_'+dr+'_original.txt',oH,fmt='%.3f')
        np.savetxt('results/mic_distributions/'+sp+'_'+dr+'_smooth.txt',sH,fmt='%.3f')
        #WRITE HISTOGRAM FOR R CLUSTER
        R=pd.read_csv('results/Rcluster/'+sp+'_'+dr+'_Rcluster.csv')
        sH=[]
        oH=[]
        for i,y in enumerate(pY):
            Ry=R[R.Year==y]
            mic=Ry.MIC
            smoothmic=mic+np.random.normal(0.0,1.0,len(mic))
            # Make regular histogram (SMOOTHMIC)
            B1=np.arange(-10,10.5,0.5)
            n1, bins1=np.histogram(smoothmic, bins=B1, density=True)                     
            # Make regular histogram (MIC)
            B2=np.arange(-10,10.5,1)
            n2, bins2=np.histogram(mic, bins=B2, density=True)
            oH.append(n2)
            sH.append(n1)
        sH=np.array(sH, dtype=float)
        oH=np.array(oH, dtype=float)
        np.savetxt('results/mic_distributions/'+sp+'_'+dr+'_Rcluster_original.txt',oH,fmt='%.3f')
        np.savetxt('results/mic_distributions/'+sp+'_'+dr+'_Rcluster_smooth.txt',sH,fmt='%.3f')
# Out:
# Staphylococcus aureus Amoxycillin clavulanate
# Staphylococcus aureus Ampicillin
# Staphylococcus aureus Ceftaroline avibactam
# Staphylococcus aureus Ceftazidime
# Staphylococcus aureus Ceftazidime avibactam
# Staphylococcus aureus Ceftriaxone
# Staphylococcus aureus Doripenem
# Staphylococcus aureus Ertapenem
# Staphylococcus aureus Imipenem
# Staphylococcus aureus Meropenem
# Staphylococcus aureus Piperacillin tazobactam
# Escherichia coli Aztreonam avibactam
# Escherichia coli Ceftaroline avibactam
# Escherichia coli Colistin
# Escherichia coli ColistinP80
# Klebsiella pneumoniae Aztreonam avibactam
# Klebsiella pneumoniae Ceftaroline avibactam
# Klebsiella pneumoniae Colistin
# Klebsiella pneumoniae ColistinP80
# Pseudomonas aeruginosa Amoxycillin clavulanate
# Pseudomonas aeruginosa Ampicillin
# Pseudomonas aeruginosa Aztreonam avibactam
# Pseudomonas aeruginosa Ceftaroline
# Pseudomonas aeruginosa Ceftaroline avibactam
# Pseudomonas aeruginosa Ceftriaxone
# Pseudomonas aeruginosa ColistinP80
# Pseudomonas aeruginosa Ertapenem
# Pseudomonas aeruginosa Minocycline
# Pseudomonas aeruginosa Tigecycline
# Enterobacter cloacae Aztreonam avibactam
# Enterobacter cloacae Ceftaroline avibactam
# Enterobacter cloacae Colistin
# Enterobacter cloacae ColistinP80
# Streptococcus pneumoniae Ampicillin
# Streptococcus pneumoniae Ceftaroline avibactam
# Streptococcus pneumoniae Ceftazidime
# Streptococcus pneumoniae Ceftazidime avibactam
# Streptococcus pneumoniae Daptomycin
# Streptococcus pneumoniae Piperacillin tazobactam
# Haemophilus influenzae Amikacin
# Haemophilus influenzae Aztreonam avibactam
# Haemophilus influenzae Ceftaroline avibactam
# Haemophilus influenzae Ceftazidime avibactam
# Acinetobacter baumannii Amoxycillin clavulanate
# Acinetobacter baumannii Ampicillin
# Acinetobacter baumannii Aztreonam
# Acinetobacter baumannii Aztreonam avibactam
# Acinetobacter baumannii Ceftaroline
# Acinetobacter baumannii Ceftaroline avibactam
# Acinetobacter baumannii Ceftazidime avibactam
# Acinetobacter baumannii ColistinP80
# Acinetobacter baumannii Ertapenem
# Acinetobacter baumannii Tigecycline
# Enterococcus faecalis Amoxycillin clavulanate

# %% [markdown]
# ## MIC DISTRIBUTIONS AND R CLUSTER (TEST)

# %%
#CREATE NEW DIRECTORY
import os
try:
    os.mkdir('results_test/mic_distributions')
except OSError as error: 
    print('mic_distributions folder already created')
try:
    os.mkdir('results_test/Rcluster')
except OSError as error: 
    print('Rcluster folder already created')

DF, pL, bP, drugs=read_dataset('test')
#GET GAUSSIAN MIXTURE FOR EACH PA PAIR
for sp in pL:
    for dr in drugs:
        BP=0
        if dr in bP[sp]:
            BP=bP[sp][dr][0]
            continue#because we have done it already!
        pY,pM,sM=mic_dist(sp,dr,DF,BP)
        if not pY: continue
        print(sp,dr)
        #GAUSSIAN MIXTURE AND R CLUSTER
        result=False
        while result==False:#sometimes the Gaussian mixture doesn't work
            try:
                extract_rcluster(sp, dr, pY, pM, sM, DF)
                Z,gmm_x=gaussian_mixture(pY, sM)
                result=True
            except:
                pass
        np.savetxt('results_test/mic_distributions/'+sp+'_'+dr+'.txt',Z,fmt='%.3f')                
        np.savetxt('results_test/mic_distributions/'+sp+'_'+dr+'_years.txt',pY, fmt='%d')
        #WRITE HISTOGRAMS
        sH=[]
        oH=[]
        for i,y in enumerate(pY):
            # Make regular histogram (SMOOTHMIC)
            B1=np.arange(-10,10.5,0.5)
            n1, bins1=np.histogram(sM[i], bins=B1, density=True)                     
            # Make regular histogram (MIC)
            B2=np.arange(-10,10.5,1)
            n2, bins2=np.histogram(pM[i], bins=B2, density=True)
            sH.append(n1)
            oH.append(n2)
        sH=np.array(sH, dtype=float)
        oH=np.array(oH, dtype=float)
        np.savetxt('results_test/mic_distributions/'+sp+'_'+dr+'_original.txt',oH,fmt='%.3f')
        np.savetxt('results_test/mic_distributions/'+sp+'_'+dr+'_smooth.txt',sH,fmt='%.3f')

# %% [markdown]
# ## MIC DISTRIBUTIONS AND R CLUSTER (INFORM)

# %%
#CREATE NEW DIRECTORY
import os
try:
    os.mkdir('results_test/mic_distributions')
except OSError as error: 
    print('mic_distributions folder already created')
try:
    os.mkdir('results_test/Rcluster')
except OSError as error: 
    print('Rcluster folder already created')

DF, pL, bP, drugs=read_dataset('inform')
#GET GAUSSIAN MIXTURE FOR EACH PA PAIR
for sp in pL:
    for dr in drugs:
        BP=0
        if dr in bP[sp]:
            BP=bP[sp][dr][0]
            continue#because we have done it already!
        pY,pM,sM=mic_dist(sp,dr,DF,BP)
        if not pY: continue
        print(sp,dr)
        #GAUSSIAN MIXTURE AND R CLUSTER
        result=False
        while result==False:#sometimes the Gaussian mixture doesn't work
            try:
                extract_rcluster(sp, dr, pY, pM, sM, DF)
                Z,gmm_x=gaussian_mixture(pY, sM)
                result=True
            except:
                pass
        np.savetxt('results_test/mic_distributions/'+sp+'_'+dr+'.txt',Z,fmt='%.3f')                
        np.savetxt('results_test/mic_distributions/'+sp+'_'+dr+'_years.txt',pY, fmt='%d')
        #WRITE HISTOGRAMS
        sH=[]
        oH=[]
        for i,y in enumerate(pY):
            # Make regular histogram (SMOOTHMIC)
            B1=np.arange(-10,10.5,0.5)
            n1, bins1=np.histogram(sM[i], bins=B1, density=True)                     
            # Make regular histogram (MIC)
            B2=np.arange(-10,10.5,1)
            n2, bins2=np.histogram(pM[i], bins=B2, density=True)
            sH.append(n1)
            oH.append(n2)
        sH=np.array(sH, dtype=float)
        oH=np.array(oH, dtype=float)
        np.savetxt('results_test/mic_distributions/'+sp+'_'+dr+'_original.txt',oH,fmt='%.3f')
        np.savetxt('results_test/mic_distributions/'+sp+'_'+dr+'_smooth.txt',sH,fmt='%.3f')

# %% [markdown]
# # CHANGEPOINT ANALYSIS
# To check if increased testing has lead to a significant MIC trend in ATLAS (Fig S7). First we need to record global average MIC and number of cases (we had previously computed it for each country):
#
# ## GLOBAL AVERAGE MIC PER YEAR

# %%
DF, pL, bP, drugs=read_dataset('atlas')
L=[]
for sp in pL:#for every pathogen
    print(sp)
    DFsp=DF[DF.Species==sp]
    if DFsp.empty: continue
    for dr in drugs:#for every drug
        DFnew=pd.DataFrame({'Year': DFsp['Year'], dr: DFsp[dr]})
        DFnew=DFnew.dropna()
        if DFnew.empty: continue
        yL=get_key(DFnew, 'Year')
        for y in yL:#for every year
            DFy=DFnew[DFnew.Year==y]
            if DFy.empty: continue
            #DATA
            BP=0#we include those PA pairs without a breakpoint
            if dr in bP[sp]:
                BP=bP[sp][dr][0]
            m=DFy[dr].mean()-BP
            merr=DFy[dr].sem()
            N=len(DFy)
            #RECORD
            L.append([sp,dr,y,m,merr,N])
#SAVE ALL IN DATAFRAME AND WRITE TO FILE
MICdf=pd.DataFrame.from_records(L, columns=['Species', 'Antibiotic', 'Year', 'Average MIC', 'Average MIC SEM', 'Number of cases'])
MICdf.to_csv('data/average_mic_per_year_complete.csv', float_format='%.3f', na_rep='NaN', index=False)
# Out:
# Staphylococcus aureus
# Escherichia coli
# Klebsiella pneumoniae
# Pseudomonas aeruginosa
# Enterobacter cloacae
# Streptococcus pneumoniae
# Haemophilus influenzae
# Acinetobacter baumannii
# Enterococcus faecalis
# Streptococcus agalactiae
# Serratia marcescens
# Klebsiella oxytoca
# Klebsiella aerogenes
# Enterococcus faecium
# Streptococcus pyogenes
# Staphylococcus epidermidis
# Citrobacter freundii
# Proteus mirabilis
# Citrobacter koseri
# Staphylococcus haemolyticus
# Bacteroides fragilis
# Stenotrophomonas maltophilia
# Morganella morganii
# Acinetobacter pitii
# Proteus vulgaris
# Enterobacter asburiae
# Acinetobacter lwoffii
# Streptococcus dysgalactiae
# Clostridioides (Clostridium) difficile
# Clostridium perfringens
# Staphylococcus hominis
# Moraxella catarrhalis
# Klebsiella variicola
# Streptococcus anginosus
# Enterobacter kobei
# Parvimonas micra
# Prevotella bivia
# Providencia stuartii
# Staphylococcus lugdunensis
# Bacteroides thetaiotaomicron
# Peptostreptococcus magnus
# Serratia liquefaciens
# Acinetobacter nosocomialis
# Staphylococcus capitis
# Haemophilus parainfluenzae
# Providencia rettgeri
# Acinetobacter, non-speciated
# Peptostreptococcus anaerobius
# Enterobacter, non-speciated
# Enterobacter agglomerans
# Bacteroides ovatus
# Finegoldia magna
# Acinetobacter ursingii
# Acinetobacter junii
# Citrobacter braakii
# Streptococcus gallolyticus
# Staphylococcus saprophyticus
# Bacteroides vulgatus
# Enterococcus avium
# Anaerococcus prevotii
# Prevotella buccae
# Prevotella melaninogenica
# Peptoniphilus harei
# Staphylococcus Coagulase Negative
# Acinetobacter haemolyticus
# Enterococcus casseliflavus
# Proteus hauseri
# Staphylococcus warneri
# Parabacteroides distasonis
# Prevotella intermedia
# Bacteroides uniformis
# Peptoniphilus asaccharolyticus
# Enterococcus gallinarum
# Acinetobacter johnsonii
# Acinetobacter radioresistens
# Enterococcus, non-speciated
# Enterobacter ludwigii
# Raoultella ornithinolytica
# Enterobacter sakazakii
# Prevotella oralis
# Clostridium innocuum
# Acinetobacter calcoaceticus
# Streptococcus constellatus
# Serratia ureilytica
# Enterococcus durans
# Acinetobacter guillouiae
# Prevotella denticola
# Prevotella disiens
# Staphylococcus simulans
# Clostridium clostridiiformis
# Serratia, non-speciated
# Clostridium ramosum
# Lelliottia amnigenus
# Pluralibacter gergoviae
# Serratia odorifera
# Citrobacter, non-speciated
# Bacteroides caccae
# Enterococcus raffinosus
# Citrobacter amalonaticus
# Clostridium sporogenes
# Proteus penneri
# Peptostreptococcus spp
# Prevotella oris
# Neisseria gonorrhoeae
# Prevotella nigrescens
# Staphylococcus caprae
# Klebsiella, non-speciated
# Clostridium sordellii
# Bacteroides stercosis
# Prevotella spp
# Raoultella planticola
# Serratia rubidaea
# Clostridium tertium
# Prevotella loescheii
# Staphylococcus sciuri
# Staphylococcus cohnii
# Clostridium butyricum
# Klebsiella ozaenae
# Clostridium hathewayi
# Acinetobacter anitratus
# Citrobacter farmeri
# Clostridium paraputrificum
# Acinetobacter baylyi
# Enterococcus hirae
# Streptococcus bovis
# Prevotella corporis
# Clostridium septicum
# Acinetobacter parvus
# Streptococcus, viridans group
# Streptococcus salivarius
# Prevotella nanceinsis
# Providencia, non-speciated
# Acinetobacter tjernbergiae
# Pseudomonas putida
# Bacteroides eggerthii
# Providencia alcalifaciens
# Anaerococcus vaginalis
# Enterobacter cancerogenus
# Clostridium bifermentans
# Clostridium spp
# Prevotella bergensis
# Streptococcus oralis
# Bacteroides capsillosis
# Enterobacter hormaechi
# Citrobacter sedlakii
# Prevotella buccalis
# Enterococcus Group D
# Klebsiella ornithinolytica
# Serratia fonticola
# Bacteroides pyogenes
# Staphylococcus schleiferi
# Streptococcus parasanguinis
# Bacteroides intestinalis
# Acinetobacter schindleri
# Bacteroides spp
# Prevotella baroniae
# Bacteroides nordii
# Serratia plymuthica
# Clostridium barati
# Streptococcus intermedius
# Prevotella salivae
# Clostridium cadaveris
# Enterobacter intermedium
# Bacteroides salersyae
# Serratia ficaria
# Clostridium citroniae
# Staphylococcus pasteuri
# Bacteroides merdeae
# Prevotella timonensis
# Peptoniphilus gorbachii
# Anaerococcus hydrogenalis
# Prevotella histicola
# Staphylococcus pseudointermedius
# Campylobacter ureolyticus
# Streptococcus lutetiensis
# Bacteroides faecis
# Staphylococcus pettenkoferi
# Clostridium glycolicum
# Peptoniphilus spp
# Clostridium subterminale
# Clostridium celerecrescens
# Clostridium sphenoides
# Clostridium bolteae
# Streptococcus sanguinis
# Citrobacter murliniae
# Enterobacter taylorae
# Staphylococcus xylosus
# Prevotella pallens
# Parabacteroides goldsteinii
# Haemophilus parahaemolyticus
# Staphylococcus intermedius
# Bacteroides dorei
# Anaerococcus tetradius
# Anaerococcus spp
# Streptococcus mitis
# Streptococcus castoreus
# Clostridium histolyticum
# Clostridium aldenense
# Peptostreptococcus lactolyticus
# Clostridium scindens
# Streptococcus canis
# Acinetobacter towneri
# Pseudomonas monteilii
# Anaerococcus murdochii
# Pseudomonas nitroreducens
# Pseudomonas mosselii
# Clostridium symbiosum
# Streptococcus, Beta Hemolytic
# Peptostreptococcus hydrogenalis
# Staphylococcus auricularis
# Parabacteroides johnsonii
# Aeromonas caviae
# Prevotella heparinolytica
# Hafnia alvei
# Aeromonas veronii
# Aeromonas hydrophila
# Pseudomonas stutzeri
# Kluyvera ascorbata
# Anaerococcus lactolyticus
# Citrobacter youngae
# Anaerococcus octavius
# Peptoniphilus indolicus
# Peptostreptococcus indolicus
# Clostridium rectum
# Clostridium novyia
# Bacteroides splanchnicus
# Clostridium hastiforme
# Clostridium cochlearium
# Prevotella maculosa
# Streptococcus equi
# Staphylococcus vitulinus
# Veillonella parvula
# Serratia grimesii
# Peptoniphilus olsenii
# Bacteroides cellulosilyticus
# Bacteroides coagulans
# Bacteroides massiliensis
# Citrobacter gillenii
# Clostridium putrificum
# Clostridium scatalogenes
# Enterobacter liquifaciens
# Enterococcus malodoratus
# Enterococcus mundtii
# Raoultella terrigena
# Eubacterium aerofaciens
# Eubacterium lentum
# Pantoea agglomerans
# Pantoea septica
# Escherichia hermanii
# Prevotella amnii
# Peptostreptococcus tetradius
# Proteus rettgeri
# Pseudomonas otitidis
# Prevotella oulorum
# Prevotella tannerae
# Peptoniphilus lacrimalis
# Burkholderia cenocepacia
# Streptococcus massiliensis
# Clostridium beijerinckii
# Pseudomonas mendocina
# Burkholderia cepacia
# Staphylococcus arlettae
# Clostridium disporicum
# Pseudomonas stewartii
# Streptococcus sanguis
# Streptococcus suis
# Bacteroides bivius
# Anaerovorax spp
# Clostridium colicanis
# Pseudomonas fluorescens
# Streptococcus gordonii
# Clostridium limosum
# Pseudomonas alcaliphila
# Cronobacter sakazakii
# Enterococcus flavescens
# Prevotella veroralis
# Escherichia fergusonii
# Escherichia vulneris
# Prevotella multiformis
# Staphylococcus hyicus
# Fusobacterium nucleatum
# Haemophilus pittmaniae
# Klebsiella rhinoscleromatis
# Acinetobacter alcaligenes

# %% [markdown]
# ## CHANGEPOINT DETECTION

# %%
DF, pL, bP, drugs=read_dataset('atlas')
DF2=pd.read_csv('data/average_mic_per_year_complete.csv')
sdL=[]
for sp, dr in itertools.product(pL, drugs):
    DFsp=DF2[(DF2.Species==sp) & (DF2.Antibiotic==dr)]
    if DFsp.empty: continue
    yL=get_key(DFsp, 'Year')
    if len(yL)<2: continue
    nL=[]
    rL=[]
    for year in yL:
        DFnew=DFsp[DFsp.Year==year]
        n=DFnew['Number of cases'].sum()
        nL.append(n)
    tau=find_changepoint(nL)
    if tau>-1:
        sdL.append([sp,dr, yL[tau]])
print(len(sdL))
#NOW CHECK WHICH OF THOSE HAVE A NEGATIVE SLOPE
special=[]
from scipy import stats
for key in sdL:
    sp=key[0]
    dr=key[1]
    BP=0
    if dr in bP[sp]:
        BP=bP[sp][dr][0]
    tau=key[2]
    #COMPUTE SLOPE
    DFdr=DF[DF.Species==sp]
    DFc=pd.DataFrame({'Year': DFdr['Year'], dr: DFdr[dr]})
    DFc=DFc.dropna()
    slope, intercept, r_value, p_value, std_err=stats.linregress(DFc['Year'], DFc[dr])
    intercept=intercept-BP
    if p_value>0.05:
        slope=0
        intercept=DFc[dr].mean()-BP
    #COMPUTE SECOND SLOPE
    DFdr=DF[(DF.Species==sp) & (DF.Year>tau-1)]
    DFc=pd.DataFrame({'Year': DFdr['Year'], dr: DFdr[dr]})
    DFc=DFc.dropna()
    yL=sorted(get_key(DFc, 'Year'))
    s1=0
    i1=DFc[dr].mean()-BP
    if len(yL)>2:
        s1, i1, r1, p1, std1=stats.linregress(DFc['Year'], DFc[dr])
        i1=i1-BP
        if p1>0.05:
            s1=0
            i1=DFc[dr].mean()-BP
    #COMPUTE THIRD SLOPE
    DFdr=DF[(DF.Species==sp) & (DF.Year<tau)]
    DFc=pd.DataFrame({'Year': DFdr['Year'], dr: DFdr[dr]})
    DFc=DFc.dropna()
    yL=sorted(get_key(DFc, 'Year'))
    s2=0
    i2=DFc[dr].mean()-BP
    if len(yL)>2:
        s2, i2, r2, p2, std2=stats.linregress(DFc['Year'], DFc[dr])
        i2=i2-BP
        if p2>0.05:
            s2=0
            i2=DFc[dr].mean()-BP
    if s1*s2<0:
        special.append([sp,dr,tau,s1,i1,s2,i2,slope,intercept])

DFstr=pd.DataFrame.from_records(special, columns=['Species', 'Antibiotic', 'Changepoint', 'Slope After', 'Intercept After', 'Slope Before', 'Intercept Before', 'Slope Global', 'Intercept Global'])
DFstr.to_csv('data/changepoint_analysis_change_in_mic.csv', index=False, float_format='%.6f')
# Out:
# 1718

# %% [markdown]
# # R CLUSTER TRENDS
#
# Data for Figs 5, 6, 8, Supp Figs 14, 17, 20)
#
# ## ATLAS TREND
# (record slopes and intercepts with %.6f, so that there is no error!)

# %%
DF, pL, bP, drugs=read_dataset('atlas')
newDF=resistant_cluster_trends(DF, pL, bP, drugs)
newDF.to_csv('results/Rcluster/resistant_cluster_trends_noBP.csv', index=False, float_format='%.6f')

# %% [markdown]
# ## TEST TREND

# %%
DF, pL, bP, drugs=read_dataset('test')
newDF=resistant_cluster_trends(DF, pL, bP, drugs)
newDF.to_csv('results_test/Rcluster/resistant_cluster_trends_noBP.csv', index=False, float_format='%.6f')

# %% [markdown]
# ## INFORM TREND

# %%
DF, pL, bP, drugs=read_dataset('inform')
newDF=resistant_cluster_trends(DF, pL, bP, drugs)
newDF.to_csv('results_inform/Rcluster/resistant_cluster_trends_noBP.csv', index=False, float_format='%.6f')

# %% [markdown]
# ## EUROPE TREND

# %%
DF, pL, bP, drugs=read_dataset('europe')
newDF=resistant_cluster_trends(DF, pL, bP, drugs)
newDF.to_csv('results/Rcluster/resistant_cluster_trends_noBP_europe.csv', index=False, float_format='%.6f')

# %% [markdown]
# ## USA TREND

# %%
DF, pL, bP, drugs=read_dataset('USA')
newDF=resistant_cluster_trends(DF, pL, bP, drugs)
newDF.to_csv('results/Rcluster/resistant_cluster_trends_noBP_usa.csv', index=False, float_format='%.6f')

# %% [markdown]
# # REST TREND

# %%
DF, pL, bP, drugs=read_dataset('rest')
newDF=resistant_cluster_trends(DF, pL, bP, drugs)
newDF.to_csv('results/Rcluster/resistant_cluster_trends_noBP_rest.csv', index=False, float_format='%.6f')

# %% [markdown]
# # RECORD DATAPOINTS IN RCLUSTER TRENDS
# Supp Fig 20D

# %%
DF, pL, bP, drugs=read_dataset('atlas')
from sklearn import mixture
import statsmodels.api as sm
from functions import *

lS=[]
lA=[]
lN=[]
lY=[]
for sp in pL:
    for dr in drugs:
        print(sp,dr)
        #GLOBAL TREND
        DFsp=DF[DF.Species==sp]
        DFc=pd.DataFrame({'Year': DFsp['Year'], 'MIC': DFsp[dr]})
        DFc=DFc.dropna()
        yL=get_key(DFc, 'Year')
        if len(yL)<2: continue
        #LISTS
        lS.append(sp)
        lA.append(dr)
        lN.append(len(DFc))
        lY.append(len(yL))
newDF=pd.DataFrame({'Species':lS, 'Antibiotic':lA, 'Datapoints':lN, 'YearRange':lY})
newDF.to_csv('results/Rcluster/resistant_cluster_trends_datapoints.csv', index=False)
# Out:
# Staphylococcus aureus Amikacin
# Staphylococcus aureus Amoxycillin clavulanate
# Staphylococcus aureus Ampicillin
# Staphylococcus aureus Ampicillin sulbactam
# Staphylococcus aureus Azithromycin
# Staphylococcus aureus Aztreonam
# Staphylococcus aureus Aztreonam avibactam
# Staphylococcus aureus Cefepime
# Staphylococcus aureus Cefoxitin
# Staphylococcus aureus Ceftaroline
# Staphylococcus aureus Ceftaroline avibactam
# Staphylococcus aureus Ceftazidime
# Staphylococcus aureus Ceftazidime avibactam
# Staphylococcus aureus Ceftriaxone
# Staphylococcus aureus Clarithromycin
# Staphylococcus aureus Clindamycin
# Staphylococcus aureus Colistin
# Staphylococcus aureus ColistinP80
# Staphylococcus aureus Daptomycin
# Staphylococcus aureus Doripenem
# Staphylococcus aureus Ertapenem
# Staphylococcus aureus Erythromycin
# Staphylococcus aureus Gentamicin
# Staphylococcus aureus Imipenem
# Staphylococcus aureus Levofloxacin
# Staphylococcus aureus Linezolid
# Staphylococcus aureus Meropenem
# Staphylococcus aureus Metronidazole
# Staphylococcus aureus Minocycline
# Staphylococcus aureus Moxifloxacin
# Staphylococcus aureus Oxacillin
# Staphylococcus aureus Penicillin
# Staphylococcus aureus Piperacillin tazobactam
# Staphylococcus aureus Quinupristin dalfopristin
# Staphylococcus aureus Teicoplanin
# Staphylococcus aureus Tigecycline
# Staphylococcus aureus Trimethoprim sulfa
# Staphylococcus aureus Vancomycin
# Escherichia coli Amikacin
# Escherichia coli Amoxycillin clavulanate
# Escherichia coli Ampicillin
# Escherichia coli Ampicillin sulbactam
# Escherichia coli Azithromycin
# Escherichia coli Aztreonam
# Escherichia coli Aztreonam avibactam
# Escherichia coli Cefepime
# Escherichia coli Cefoxitin
# Escherichia coli Ceftaroline
# Escherichia coli Ceftaroline avibactam
# Escherichia coli Ceftazidime
# Escherichia coli Ceftazidime avibactam
# Escherichia coli Ceftriaxone
# Escherichia coli Clarithromycin
# Escherichia coli Clindamycin
# Escherichia coli Colistin
# Escherichia coli ColistinP80
# Escherichia coli Daptomycin
# Escherichia coli Doripenem
# Escherichia coli Ertapenem
# Escherichia coli Erythromycin
# Escherichia coli Gentamicin
# Escherichia coli Imipenem
# Escherichia coli Levofloxacin
# Escherichia coli Linezolid
# Escherichia coli Meropenem
# Escherichia coli Metronidazole
# Escherichia coli Minocycline
# Escherichia coli Moxifloxacin
# Escherichia coli Oxacillin
# Escherichia coli Penicillin
# Escherichia coli Piperacillin tazobactam
# Escherichia coli Quinupristin dalfopristin
# Escherichia coli Teicoplanin
# Escherichia coli Tigecycline
# Escherichia coli Trimethoprim sulfa
# Escherichia coli Vancomycin
# Klebsiella pneumoniae Amikacin
# Klebsiella pneumoniae Amoxycillin clavulanate
# Klebsiella pneumoniae Ampicillin
# Klebsiella pneumoniae Ampicillin sulbactam
# Klebsiella pneumoniae Azithromycin
# Klebsiella pneumoniae Aztreonam
# Klebsiella pneumoniae Aztreonam avibactam
# Klebsiella pneumoniae Cefepime
# Klebsiella pneumoniae Cefoxitin
# Klebsiella pneumoniae Ceftaroline
# Klebsiella pneumoniae Ceftaroline avibactam
# Klebsiella pneumoniae Ceftazidime
# Klebsiella pneumoniae Ceftazidime avibactam
# Klebsiella pneumoniae Ceftriaxone
# Klebsiella pneumoniae Clarithromycin
# Klebsiella pneumoniae Clindamycin
# Klebsiella pneumoniae Colistin
# Klebsiella pneumoniae ColistinP80
# Klebsiella pneumoniae Daptomycin
# Klebsiella pneumoniae Doripenem
# Klebsiella pneumoniae Ertapenem
# Klebsiella pneumoniae Erythromycin
# Klebsiella pneumoniae Gentamicin
# Klebsiella pneumoniae Imipenem
# Klebsiella pneumoniae Levofloxacin
# Klebsiella pneumoniae Linezolid
# Klebsiella pneumoniae Meropenem
# Klebsiella pneumoniae Metronidazole
# Klebsiella pneumoniae Minocycline
# Klebsiella pneumoniae Moxifloxacin
# Klebsiella pneumoniae Oxacillin
# Klebsiella pneumoniae Penicillin
# Klebsiella pneumoniae Piperacillin tazobactam
# Klebsiella pneumoniae Quinupristin dalfopristin
# Klebsiella pneumoniae Teicoplanin
# Klebsiella pneumoniae Tigecycline
# Klebsiella pneumoniae Trimethoprim sulfa
# Klebsiella pneumoniae Vancomycin
# Pseudomonas aeruginosa Amikacin
# Pseudomonas aeruginosa Amoxycillin clavulanate
# Pseudomonas aeruginosa Ampicillin
# Pseudomonas aeruginosa Ampicillin sulbactam
# Pseudomonas aeruginosa Azithromycin
# Pseudomonas aeruginosa Aztreonam
# Pseudomonas aeruginosa Aztreonam avibactam
# Pseudomonas aeruginosa Cefepime
# Pseudomonas aeruginosa Cefoxitin
# Pseudomonas aeruginosa Ceftaroline
# Pseudomonas aeruginosa Ceftaroline avibactam
# Pseudomonas aeruginosa Ceftazidime
# Pseudomonas aeruginosa Ceftazidime avibactam
# Pseudomonas aeruginosa Ceftriaxone
# Pseudomonas aeruginosa Clarithromycin
# Pseudomonas aeruginosa Clindamycin
# Pseudomonas aeruginosa Colistin
# Pseudomonas aeruginosa ColistinP80
# Pseudomonas aeruginosa Daptomycin
# Pseudomonas aeruginosa Doripenem
# Pseudomonas aeruginosa Ertapenem
# Pseudomonas aeruginosa Erythromycin
# Pseudomonas aeruginosa Gentamicin
# Pseudomonas aeruginosa Imipenem
# Pseudomonas aeruginosa Levofloxacin
# Pseudomonas aeruginosa Linezolid
# Pseudomonas aeruginosa Meropenem
# Pseudomonas aeruginosa Metronidazole
# Pseudomonas aeruginosa Minocycline
# Pseudomonas aeruginosa Moxifloxacin
# Pseudomonas aeruginosa Oxacillin
# Pseudomonas aeruginosa Penicillin
# Pseudomonas aeruginosa Piperacillin tazobactam
# Pseudomonas aeruginosa Quinupristin dalfopristin
# Pseudomonas aeruginosa Teicoplanin
# Pseudomonas aeruginosa Tigecycline
# Pseudomonas aeruginosa Trimethoprim sulfa
# Pseudomonas aeruginosa Vancomycin
# Enterobacter cloacae Amikacin
# Enterobacter cloacae Amoxycillin clavulanate
# Enterobacter cloacae Ampicillin
# Enterobacter cloacae Ampicillin sulbactam
# Enterobacter cloacae Azithromycin
# Enterobacter cloacae Aztreonam
# Enterobacter cloacae Aztreonam avibactam
# Enterobacter cloacae Cefepime
# Enterobacter cloacae Cefoxitin
# Enterobacter cloacae Ceftaroline
# Enterobacter cloacae Ceftaroline avibactam
# Enterobacter cloacae Ceftazidime
# Enterobacter cloacae Ceftazidime avibactam
# Enterobacter cloacae Ceftriaxone
# Enterobacter cloacae Clarithromycin
# Enterobacter cloacae Clindamycin
# Enterobacter cloacae Colistin
# Enterobacter cloacae ColistinP80
# Enterobacter cloacae Daptomycin
# Enterobacter cloacae Doripenem
# Enterobacter cloacae Ertapenem
# Enterobacter cloacae Erythromycin
# Enterobacter cloacae Gentamicin
# Enterobacter cloacae Imipenem
# Enterobacter cloacae Levofloxacin
# Enterobacter cloacae Linezolid
# Enterobacter cloacae Meropenem
# Enterobacter cloacae Metronidazole
# Enterobacter cloacae Minocycline
# Enterobacter cloacae Moxifloxacin
# Enterobacter cloacae Oxacillin
# Enterobacter cloacae Penicillin
# Enterobacter cloacae Piperacillin tazobactam
# Enterobacter cloacae Quinupristin dalfopristin
# Enterobacter cloacae Teicoplanin
# Enterobacter cloacae Tigecycline
# Enterobacter cloacae Trimethoprim sulfa
# Enterobacter cloacae Vancomycin
# Streptococcus pneumoniae Amikacin
# Streptococcus pneumoniae Amoxycillin clavulanate
# Streptococcus pneumoniae Ampicillin
# Streptococcus pneumoniae Ampicillin sulbactam
# Streptococcus pneumoniae Azithromycin
# Streptococcus pneumoniae Aztreonam
# Streptococcus pneumoniae Aztreonam avibactam
# Streptococcus pneumoniae Cefepime
# Streptococcus pneumoniae Cefoxitin
# Streptococcus pneumoniae Ceftaroline
# Streptococcus pneumoniae Ceftaroline avibactam
# Streptococcus pneumoniae Ceftazidime
# Streptococcus pneumoniae Ceftazidime avibactam
# Streptococcus pneumoniae Ceftriaxone
# Streptococcus pneumoniae Clarithromycin
# Streptococcus pneumoniae Clindamycin
# Streptococcus pneumoniae Colistin
# Streptococcus pneumoniae ColistinP80
# Streptococcus pneumoniae Daptomycin
# Streptococcus pneumoniae Doripenem
# Streptococcus pneumoniae Ertapenem
# Streptococcus pneumoniae Erythromycin
# Streptococcus pneumoniae Gentamicin
# Streptococcus pneumoniae Imipenem
# Streptococcus pneumoniae Levofloxacin
# Streptococcus pneumoniae Linezolid
# Streptococcus pneumoniae Meropenem
# Streptococcus pneumoniae Metronidazole
# Streptococcus pneumoniae Minocycline
# Streptococcus pneumoniae Moxifloxacin
# Streptococcus pneumoniae Oxacillin
# Streptococcus pneumoniae Penicillin
# Streptococcus pneumoniae Piperacillin tazobactam
# Streptococcus pneumoniae Quinupristin dalfopristin
# Streptococcus pneumoniae Teicoplanin
# Streptococcus pneumoniae Tigecycline
# Streptococcus pneumoniae Trimethoprim sulfa
# Streptococcus pneumoniae Vancomycin
# Haemophilus influenzae Amikacin
# Haemophilus influenzae Amoxycillin clavulanate
# Haemophilus influenzae Ampicillin
# Haemophilus influenzae Ampicillin sulbactam
# Haemophilus influenzae Azithromycin
# Haemophilus influenzae Aztreonam
# Haemophilus influenzae Aztreonam avibactam
# Haemophilus influenzae Cefepime
# Haemophilus influenzae Cefoxitin
# Haemophilus influenzae Ceftaroline
# Haemophilus influenzae Ceftaroline avibactam
# Haemophilus influenzae Ceftazidime
# Haemophilus influenzae Ceftazidime avibactam
# Haemophilus influenzae Ceftriaxone
# Haemophilus influenzae Clarithromycin
# Haemophilus influenzae Clindamycin
# Haemophilus influenzae Colistin
# Haemophilus influenzae ColistinP80
# Haemophilus influenzae Daptomycin
# Haemophilus influenzae Doripenem
# Haemophilus influenzae Ertapenem
# Haemophilus influenzae Erythromycin
# Haemophilus influenzae Gentamicin
# Haemophilus influenzae Imipenem
# Haemophilus influenzae Levofloxacin
# Haemophilus influenzae Linezolid
# Haemophilus influenzae Meropenem
# Haemophilus influenzae Metronidazole
# Haemophilus influenzae Minocycline
# Haemophilus influenzae Moxifloxacin
# Haemophilus influenzae Oxacillin
# Haemophilus influenzae Penicillin
# Haemophilus influenzae Piperacillin tazobactam
# Haemophilus influenzae Quinupristin dalfopristin
# Haemophilus influenzae Teicoplanin
# Haemophilus influenzae Tigecycline
# Haemophilus influenzae Trimethoprim sulfa
# Haemophilus influenzae Vancomycin
# Acinetobacter baumannii Amikacin
# Acinetobacter baumannii Amoxycillin clavulanate
# Acinetobacter baumannii Ampicillin
# Acinetobacter baumannii Ampicillin sulbactam
# Acinetobacter baumannii Azithromycin
# Acinetobacter baumannii Aztreonam
# Acinetobacter baumannii Aztreonam avibactam
# Acinetobacter baumannii Cefepime
# Acinetobacter baumannii Cefoxitin
# Acinetobacter baumannii Ceftaroline
# Acinetobacter baumannii Ceftaroline avibactam
# Acinetobacter baumannii Ceftazidime
# Acinetobacter baumannii Ceftazidime avibactam
# Acinetobacter baumannii Ceftriaxone
# Acinetobacter baumannii Clarithromycin
# Acinetobacter baumannii Clindamycin
# Acinetobacter baumannii Colistin
# Acinetobacter baumannii ColistinP80
# Acinetobacter baumannii Daptomycin
# Acinetobacter baumannii Doripenem
# Acinetobacter baumannii Ertapenem
# Acinetobacter baumannii Erythromycin
# Acinetobacter baumannii Gentamicin
# Acinetobacter baumannii Imipenem
# Acinetobacter baumannii Levofloxacin
# Acinetobacter baumannii Linezolid
# Acinetobacter baumannii Meropenem
# Acinetobacter baumannii Metronidazole
# Acinetobacter baumannii Minocycline
# Acinetobacter baumannii Moxifloxacin
# Acinetobacter baumannii Oxacillin
# Acinetobacter baumannii Penicillin
# Acinetobacter baumannii Piperacillin tazobactam
# Acinetobacter baumannii Quinupristin dalfopristin
# Acinetobacter baumannii Teicoplanin
# Acinetobacter baumannii Tigecycline
# Acinetobacter baumannii Trimethoprim sulfa
# Acinetobacter baumannii Vancomycin
# Enterococcus faecalis Amikacin
# Enterococcus faecalis Amoxycillin clavulanate
# Enterococcus faecalis Ampicillin
# Enterococcus faecalis Ampicillin sulbactam
# Enterococcus faecalis Azithromycin
# Enterococcus faecalis Aztreonam
# Enterococcus faecalis Aztreonam avibactam
# Enterococcus faecalis Cefepime
# Enterococcus faecalis Cefoxitin
# Enterococcus faecalis Ceftaroline
# Enterococcus faecalis Ceftaroline avibactam
# Enterococcus faecalis Ceftazidime
# Enterococcus faecalis Ceftazidime avibactam
# Enterococcus faecalis Ceftriaxone
# Enterococcus faecalis Clarithromycin
# Enterococcus faecalis Clindamycin
# Enterococcus faecalis Colistin
# Enterococcus faecalis ColistinP80
# Enterococcus faecalis Daptomycin
# Enterococcus faecalis Doripenem
# Enterococcus faecalis Ertapenem
# Enterococcus faecalis Erythromycin
# Enterococcus faecalis Gentamicin
# Enterococcus faecalis Imipenem
# Enterococcus faecalis Levofloxacin
# Enterococcus faecalis Linezolid
# Enterococcus faecalis Meropenem
# Enterococcus faecalis Metronidazole
# Enterococcus faecalis Minocycline
# Enterococcus faecalis Moxifloxacin
# Enterococcus faecalis Oxacillin
# Enterococcus faecalis Penicillin
# Enterococcus faecalis Piperacillin tazobactam
# Enterococcus faecalis Quinupristin dalfopristin
# Enterococcus faecalis Teicoplanin
# Enterococcus faecalis Tigecycline
# Enterococcus faecalis Trimethoprim sulfa
# Enterococcus faecalis Vancomycin
# Streptococcus agalactiae Amikacin
# Streptococcus agalactiae Amoxycillin clavulanate
# Streptococcus agalactiae Ampicillin
# Streptococcus agalactiae Ampicillin sulbactam
# Streptococcus agalactiae Azithromycin
# Streptococcus agalactiae Aztreonam
# Streptococcus agalactiae Aztreonam avibactam
# Streptococcus agalactiae Cefepime
# Streptococcus agalactiae Cefoxitin
# Streptococcus agalactiae Ceftaroline
# Streptococcus agalactiae Ceftaroline avibactam
# Streptococcus agalactiae Ceftazidime
# Streptococcus agalactiae Ceftazidime avibactam
# Streptococcus agalactiae Ceftriaxone
# Streptococcus agalactiae Clarithromycin
# Streptococcus agalactiae Clindamycin
# Streptococcus agalactiae Colistin
# Streptococcus agalactiae ColistinP80
# Streptococcus agalactiae Daptomycin
# Streptococcus agalactiae Doripenem
# Streptococcus agalactiae Ertapenem
# Streptococcus agalactiae Erythromycin
# Streptococcus agalactiae Gentamicin
# Streptococcus agalactiae Imipenem
# Streptococcus agalactiae Levofloxacin
# Streptococcus agalactiae Linezolid
# Streptococcus agalactiae Meropenem
# Streptococcus agalactiae Metronidazole
# Streptococcus agalactiae Minocycline
# Streptococcus agalactiae Moxifloxacin
# Streptococcus agalactiae Oxacillin
# Streptococcus agalactiae Penicillin
# Streptococcus agalactiae Piperacillin tazobactam
# Streptococcus agalactiae Quinupristin dalfopristin
# Streptococcus agalactiae Teicoplanin
# Streptococcus agalactiae Tigecycline
# Streptococcus agalactiae Trimethoprim sulfa
# Streptococcus agalactiae Vancomycin
# Serratia marcescens Amikacin
# Serratia marcescens Amoxycillin clavulanate
# Serratia marcescens Ampicillin
# Serratia marcescens Ampicillin sulbactam
# Serratia marcescens Azithromycin
# Serratia marcescens Aztreonam
# Serratia marcescens Aztreonam avibactam
# Serratia marcescens Cefepime
# Serratia marcescens Cefoxitin
# Serratia marcescens Ceftaroline
# Serratia marcescens Ceftaroline avibactam
# Serratia marcescens Ceftazidime
# Serratia marcescens Ceftazidime avibactam
# Serratia marcescens Ceftriaxone
# Serratia marcescens Clarithromycin
# Serratia marcescens Clindamycin
# Serratia marcescens Colistin
# Serratia marcescens ColistinP80
# Serratia marcescens Daptomycin
# Serratia marcescens Doripenem
# Serratia marcescens Ertapenem
# Serratia marcescens Erythromycin
# Serratia marcescens Gentamicin
# Serratia marcescens Imipenem
# Serratia marcescens Levofloxacin
# Serratia marcescens Linezolid
# Serratia marcescens Meropenem
# Serratia marcescens Metronidazole
# Serratia marcescens Minocycline
# Serratia marcescens Moxifloxacin
# Serratia marcescens Oxacillin
# Serratia marcescens Penicillin
# Serratia marcescens Piperacillin tazobactam
# Serratia marcescens Quinupristin dalfopristin
# Serratia marcescens Teicoplanin
# Serratia marcescens Tigecycline
# Serratia marcescens Trimethoprim sulfa
# Serratia marcescens Vancomycin
# Klebsiella oxytoca Amikacin
# Klebsiella oxytoca Amoxycillin clavulanate
# Klebsiella oxytoca Ampicillin
# Klebsiella oxytoca Ampicillin sulbactam
# Klebsiella oxytoca Azithromycin
# Klebsiella oxytoca Aztreonam
# Klebsiella oxytoca Aztreonam avibactam
# Klebsiella oxytoca Cefepime
# Klebsiella oxytoca Cefoxitin
# Klebsiella oxytoca Ceftaroline
# Klebsiella oxytoca Ceftaroline avibactam
# Klebsiella oxytoca Ceftazidime
# Klebsiella oxytoca Ceftazidime avibactam
# Klebsiella oxytoca Ceftriaxone
# Klebsiella oxytoca Clarithromycin
# Klebsiella oxytoca Clindamycin
# Klebsiella oxytoca Colistin
# Klebsiella oxytoca ColistinP80
# Klebsiella oxytoca Daptomycin
# Klebsiella oxytoca Doripenem
# Klebsiella oxytoca Ertapenem
# Klebsiella oxytoca Erythromycin
# Klebsiella oxytoca Gentamicin
# Klebsiella oxytoca Imipenem
# Klebsiella oxytoca Levofloxacin
# Klebsiella oxytoca Linezolid
# Klebsiella oxytoca Meropenem
# Klebsiella oxytoca Metronidazole
# Klebsiella oxytoca Minocycline
# Klebsiella oxytoca Moxifloxacin
# Klebsiella oxytoca Oxacillin
# Klebsiella oxytoca Penicillin
# Klebsiella oxytoca Piperacillin tazobactam
# Klebsiella oxytoca Quinupristin dalfopristin
# Klebsiella oxytoca Teicoplanin
# Klebsiella oxytoca Tigecycline
# Klebsiella oxytoca Trimethoprim sulfa
# Klebsiella oxytoca Vancomycin
# Klebsiella aerogenes Amikacin
# Klebsiella aerogenes Amoxycillin clavulanate
# Klebsiella aerogenes Ampicillin
# Klebsiella aerogenes Ampicillin sulbactam
# Klebsiella aerogenes Azithromycin
# Klebsiella aerogenes Aztreonam
# Klebsiella aerogenes Aztreonam avibactam
# Klebsiella aerogenes Cefepime
# Klebsiella aerogenes Cefoxitin
# Klebsiella aerogenes Ceftaroline
# Klebsiella aerogenes Ceftaroline avibactam
# Klebsiella aerogenes Ceftazidime
# Klebsiella aerogenes Ceftazidime avibactam
# Klebsiella aerogenes Ceftriaxone
# Klebsiella aerogenes Clarithromycin
# Klebsiella aerogenes Clindamycin
# Klebsiella aerogenes Colistin
# Klebsiella aerogenes ColistinP80
# Klebsiella aerogenes Daptomycin
# Klebsiella aerogenes Doripenem
# Klebsiella aerogenes Ertapenem
# Klebsiella aerogenes Erythromycin
# Klebsiella aerogenes Gentamicin
# Klebsiella aerogenes Imipenem
# Klebsiella aerogenes Levofloxacin
# Klebsiella aerogenes Linezolid
# Klebsiella aerogenes Meropenem
# Klebsiella aerogenes Metronidazole
# Klebsiella aerogenes Minocycline
# Klebsiella aerogenes Moxifloxacin
# Klebsiella aerogenes Oxacillin
# Klebsiella aerogenes Penicillin
# Klebsiella aerogenes Piperacillin tazobactam
# Klebsiella aerogenes Quinupristin dalfopristin
# Klebsiella aerogenes Teicoplanin
# Klebsiella aerogenes Tigecycline
# Klebsiella aerogenes Trimethoprim sulfa
# Klebsiella aerogenes Vancomycin
# Enterococcus faecium Amikacin
# Enterococcus faecium Amoxycillin clavulanate
# Enterococcus faecium Ampicillin
# Enterococcus faecium Ampicillin sulbactam
# Enterococcus faecium Azithromycin
# Enterococcus faecium Aztreonam
# Enterococcus faecium Aztreonam avibactam
# Enterococcus faecium Cefepime
# Enterococcus faecium Cefoxitin
# Enterococcus faecium Ceftaroline
# Enterococcus faecium Ceftaroline avibactam
# Enterococcus faecium Ceftazidime
# Enterococcus faecium Ceftazidime avibactam
# Enterococcus faecium Ceftriaxone
# Enterococcus faecium Clarithromycin
# Enterococcus faecium Clindamycin
# Enterococcus faecium Colistin
# Enterococcus faecium ColistinP80
# Enterococcus faecium Daptomycin
# Enterococcus faecium Doripenem
# Enterococcus faecium Ertapenem
# Enterococcus faecium Erythromycin
# Enterococcus faecium Gentamicin
# Enterococcus faecium Imipenem
# Enterococcus faecium Levofloxacin
# Enterococcus faecium Linezolid
# Enterococcus faecium Meropenem
# Enterococcus faecium Metronidazole
# Enterococcus faecium Minocycline
# Enterococcus faecium Moxifloxacin
# Enterococcus faecium Oxacillin
# Enterococcus faecium Penicillin
# Enterococcus faecium Piperacillin tazobactam
# Enterococcus faecium Quinupristin dalfopristin
# Enterococcus faecium Teicoplanin
# Enterococcus faecium Tigecycline
# Enterococcus faecium Trimethoprim sulfa
# Enterococcus faecium Vancomycin
# Streptococcus pyogenes Amikacin
# Streptococcus pyogenes Amoxycillin clavulanate
# Streptococcus pyogenes Ampicillin
# Streptococcus pyogenes Ampicillin sulbactam
# Streptococcus pyogenes Azithromycin
# Streptococcus pyogenes Aztreonam
# Streptococcus pyogenes Aztreonam avibactam
# Streptococcus pyogenes Cefepime
# Streptococcus pyogenes Cefoxitin
# Streptococcus pyogenes Ceftaroline
# Streptococcus pyogenes Ceftaroline avibactam
# Streptococcus pyogenes Ceftazidime
# Streptococcus pyogenes Ceftazidime avibactam
# Streptococcus pyogenes Ceftriaxone
# Streptococcus pyogenes Clarithromycin
# Streptococcus pyogenes Clindamycin
# Streptococcus pyogenes Colistin
# Streptococcus pyogenes ColistinP80
# Streptococcus pyogenes Daptomycin
# Streptococcus pyogenes Doripenem
# Streptococcus pyogenes Ertapenem
# Streptococcus pyogenes Erythromycin
# Streptococcus pyogenes Gentamicin
# Streptococcus pyogenes Imipenem
# Streptococcus pyogenes Levofloxacin
# Streptococcus pyogenes Linezolid
# Streptococcus pyogenes Meropenem
# Streptococcus pyogenes Metronidazole
# Streptococcus pyogenes Minocycline
# Streptococcus pyogenes Moxifloxacin
# Streptococcus pyogenes Oxacillin
# Streptococcus pyogenes Penicillin
# Streptococcus pyogenes Piperacillin tazobactam
# Streptococcus pyogenes Quinupristin dalfopristin
# Streptococcus pyogenes Teicoplanin
# Streptococcus pyogenes Tigecycline
# Streptococcus pyogenes Trimethoprim sulfa
# Streptococcus pyogenes Vancomycin
# Staphylococcus epidermidis Amikacin
# Staphylococcus epidermidis Amoxycillin clavulanate
# Staphylococcus epidermidis Ampicillin
# Staphylococcus epidermidis Ampicillin sulbactam
# Staphylococcus epidermidis Azithromycin
# Staphylococcus epidermidis Aztreonam
# Staphylococcus epidermidis Aztreonam avibactam
# Staphylococcus epidermidis Cefepime
# Staphylococcus epidermidis Cefoxitin
# Staphylococcus epidermidis Ceftaroline
# Staphylococcus epidermidis Ceftaroline avibactam
# Staphylococcus epidermidis Ceftazidime
# Staphylococcus epidermidis Ceftazidime avibactam
# Staphylococcus epidermidis Ceftriaxone
# Staphylococcus epidermidis Clarithromycin
# Staphylococcus epidermidis Clindamycin
# Staphylococcus epidermidis Colistin
# Staphylococcus epidermidis ColistinP80
# Staphylococcus epidermidis Daptomycin
# Staphylococcus epidermidis Doripenem
# Staphylococcus epidermidis Ertapenem
# Staphylococcus epidermidis Erythromycin
# Staphylococcus epidermidis Gentamicin
# Staphylococcus epidermidis Imipenem
# Staphylococcus epidermidis Levofloxacin
# Staphylococcus epidermidis Linezolid
# Staphylococcus epidermidis Meropenem
# Staphylococcus epidermidis Metronidazole
# Staphylococcus epidermidis Minocycline
# Staphylococcus epidermidis Moxifloxacin
# Staphylococcus epidermidis Oxacillin
# Staphylococcus epidermidis Penicillin
# Staphylococcus epidermidis Piperacillin tazobactam
# Staphylococcus epidermidis Quinupristin dalfopristin
# Staphylococcus epidermidis Teicoplanin
# Staphylococcus epidermidis Tigecycline
# Staphylococcus epidermidis Trimethoprim sulfa
# Staphylococcus epidermidis Vancomycin
# Citrobacter freundii Amikacin
# Citrobacter freundii Amoxycillin clavulanate
# Citrobacter freundii Ampicillin
# Citrobacter freundii Ampicillin sulbactam
# Citrobacter freundii Azithromycin
# Citrobacter freundii Aztreonam
# Citrobacter freundii Aztreonam avibactam
# Citrobacter freundii Cefepime
# Citrobacter freundii Cefoxitin
# Citrobacter freundii Ceftaroline
# Citrobacter freundii Ceftaroline avibactam
# Citrobacter freundii Ceftazidime
# Citrobacter freundii Ceftazidime avibactam
# Citrobacter freundii Ceftriaxone
# Citrobacter freundii Clarithromycin
# Citrobacter freundii Clindamycin
# Citrobacter freundii Colistin
# Citrobacter freundii ColistinP80
# Citrobacter freundii Daptomycin
# Citrobacter freundii Doripenem
# Citrobacter freundii Ertapenem
# Citrobacter freundii Erythromycin
# Citrobacter freundii Gentamicin
# Citrobacter freundii Imipenem
# Citrobacter freundii Levofloxacin
# Citrobacter freundii Linezolid
# Citrobacter freundii Meropenem
# Citrobacter freundii Metronidazole
# Citrobacter freundii Minocycline
# Citrobacter freundii Moxifloxacin
# Citrobacter freundii Oxacillin
# Citrobacter freundii Penicillin
# Citrobacter freundii Piperacillin tazobactam
# Citrobacter freundii Quinupristin dalfopristin
# Citrobacter freundii Teicoplanin
# Citrobacter freundii Tigecycline
# Citrobacter freundii Trimethoprim sulfa
# Citrobacter freundii Vancomycin
# Proteus mirabilis Amikacin
# Proteus mirabilis Amoxycillin clavulanate
# Proteus mirabilis Ampicillin
# Proteus mirabilis Ampicillin sulbactam
# Proteus mirabilis Azithromycin
# Proteus mirabilis Aztreonam
# Proteus mirabilis Aztreonam avibactam
# Proteus mirabilis Cefepime
# Proteus mirabilis Cefoxitin
# Proteus mirabilis Ceftaroline
# Proteus mirabilis Ceftaroline avibactam
# Proteus mirabilis Ceftazidime
# Proteus mirabilis Ceftazidime avibactam
# Proteus mirabilis Ceftriaxone
# Proteus mirabilis Clarithromycin
# Proteus mirabilis Clindamycin
# Proteus mirabilis Colistin
# Proteus mirabilis ColistinP80
# Proteus mirabilis Daptomycin
# Proteus mirabilis Doripenem
# Proteus mirabilis Ertapenem
# Proteus mirabilis Erythromycin
# Proteus mirabilis Gentamicin
# Proteus mirabilis Imipenem
# Proteus mirabilis Levofloxacin
# Proteus mirabilis Linezolid
# Proteus mirabilis Meropenem
# Proteus mirabilis Metronidazole
# Proteus mirabilis Minocycline
# Proteus mirabilis Moxifloxacin
# Proteus mirabilis Oxacillin
# Proteus mirabilis Penicillin
# Proteus mirabilis Piperacillin tazobactam
# Proteus mirabilis Quinupristin dalfopristin
# Proteus mirabilis Teicoplanin
# Proteus mirabilis Tigecycline
# Proteus mirabilis Trimethoprim sulfa
# Proteus mirabilis Vancomycin
# Citrobacter koseri Amikacin
# Citrobacter koseri Amoxycillin clavulanate
# Citrobacter koseri Ampicillin
# Citrobacter koseri Ampicillin sulbactam
# Citrobacter koseri Azithromycin
# Citrobacter koseri Aztreonam
# Citrobacter koseri Aztreonam avibactam
# Citrobacter koseri Cefepime
# Citrobacter koseri Cefoxitin
# Citrobacter koseri Ceftaroline
# Citrobacter koseri Ceftaroline avibactam
# Citrobacter koseri Ceftazidime
# Citrobacter koseri Ceftazidime avibactam
# Citrobacter koseri Ceftriaxone
# Citrobacter koseri Clarithromycin
# Citrobacter koseri Clindamycin
# Citrobacter koseri Colistin
# Citrobacter koseri ColistinP80
# Citrobacter koseri Daptomycin
# Citrobacter koseri Doripenem
# Citrobacter koseri Ertapenem
# Citrobacter koseri Erythromycin
# Citrobacter koseri Gentamicin
# Citrobacter koseri Imipenem
# Citrobacter koseri Levofloxacin
# Citrobacter koseri Linezolid
# Citrobacter koseri Meropenem
# Citrobacter koseri Metronidazole
# Citrobacter koseri Minocycline
# Citrobacter koseri Moxifloxacin
# Citrobacter koseri Oxacillin
# Citrobacter koseri Penicillin
# Citrobacter koseri Piperacillin tazobactam
# Citrobacter koseri Quinupristin dalfopristin
# Citrobacter koseri Teicoplanin
# Citrobacter koseri Tigecycline
# Citrobacter koseri Trimethoprim sulfa
# Citrobacter koseri Vancomycin
# Staphylococcus haemolyticus Amikacin
# Staphylococcus haemolyticus Amoxycillin clavulanate
# Staphylococcus haemolyticus Ampicillin
# Staphylococcus haemolyticus Ampicillin sulbactam
# Staphylococcus haemolyticus Azithromycin
# Staphylococcus haemolyticus Aztreonam
# Staphylococcus haemolyticus Aztreonam avibactam
# Staphylococcus haemolyticus Cefepime
# Staphylococcus haemolyticus Cefoxitin
# Staphylococcus haemolyticus Ceftaroline
# Staphylococcus haemolyticus Ceftaroline avibactam
# Staphylococcus haemolyticus Ceftazidime
# Staphylococcus haemolyticus Ceftazidime avibactam
# Staphylococcus haemolyticus Ceftriaxone
# Staphylococcus haemolyticus Clarithromycin
# Staphylococcus haemolyticus Clindamycin
# Staphylococcus haemolyticus Colistin
# Staphylococcus haemolyticus ColistinP80
# Staphylococcus haemolyticus Daptomycin
# Staphylococcus haemolyticus Doripenem
# Staphylococcus haemolyticus Ertapenem
# Staphylococcus haemolyticus Erythromycin
# Staphylococcus haemolyticus Gentamicin
# Staphylococcus haemolyticus Imipenem
# Staphylococcus haemolyticus Levofloxacin
# Staphylococcus haemolyticus Linezolid
# Staphylococcus haemolyticus Meropenem
# Staphylococcus haemolyticus Metronidazole
# Staphylococcus haemolyticus Minocycline
# Staphylococcus haemolyticus Moxifloxacin
# Staphylococcus haemolyticus Oxacillin
# Staphylococcus haemolyticus Penicillin
# Staphylococcus haemolyticus Piperacillin tazobactam
# Staphylococcus haemolyticus Quinupristin dalfopristin
# Staphylococcus haemolyticus Teicoplanin
# Staphylococcus haemolyticus Tigecycline
# Staphylococcus haemolyticus Trimethoprim sulfa
# Staphylococcus haemolyticus Vancomycin
# Bacteroides fragilis Amikacin
# Bacteroides fragilis Amoxycillin clavulanate
# Bacteroides fragilis Ampicillin
# Bacteroides fragilis Ampicillin sulbactam
# Bacteroides fragilis Azithromycin
# Bacteroides fragilis Aztreonam
# Bacteroides fragilis Aztreonam avibactam
# Bacteroides fragilis Cefepime
# Bacteroides fragilis Cefoxitin
# Bacteroides fragilis Ceftaroline
# Bacteroides fragilis Ceftaroline avibactam
# Bacteroides fragilis Ceftazidime
# Bacteroides fragilis Ceftazidime avibactam
# Bacteroides fragilis Ceftriaxone
# Bacteroides fragilis Clarithromycin
# Bacteroides fragilis Clindamycin
# Bacteroides fragilis Colistin
# Bacteroides fragilis ColistinP80
# Bacteroides fragilis Daptomycin
# Bacteroides fragilis Doripenem
# Bacteroides fragilis Ertapenem
# Bacteroides fragilis Erythromycin
# Bacteroides fragilis Gentamicin
# Bacteroides fragilis Imipenem
# Bacteroides fragilis Levofloxacin
# Bacteroides fragilis Linezolid
# Bacteroides fragilis Meropenem
# Bacteroides fragilis Metronidazole
# Bacteroides fragilis Minocycline
# Bacteroides fragilis Moxifloxacin
# Bacteroides fragilis Oxacillin
# Bacteroides fragilis Penicillin
# Bacteroides fragilis Piperacillin tazobactam
# Bacteroides fragilis Quinupristin dalfopristin
# Bacteroides fragilis Teicoplanin
# Bacteroides fragilis Tigecycline
# Bacteroides fragilis Trimethoprim sulfa
# Bacteroides fragilis Vancomycin
# Stenotrophomonas maltophilia Amikacin
# Stenotrophomonas maltophilia Amoxycillin clavulanate
# Stenotrophomonas maltophilia Ampicillin
# Stenotrophomonas maltophilia Ampicillin sulbactam
# Stenotrophomonas maltophilia Azithromycin
# Stenotrophomonas maltophilia Aztreonam
# Stenotrophomonas maltophilia Aztreonam avibactam
# Stenotrophomonas maltophilia Cefepime
# Stenotrophomonas maltophilia Cefoxitin
# Stenotrophomonas maltophilia Ceftaroline
# Stenotrophomonas maltophilia Ceftaroline avibactam
# Stenotrophomonas maltophilia Ceftazidime
# Stenotrophomonas maltophilia Ceftazidime avibactam
# Stenotrophomonas maltophilia Ceftriaxone
# Stenotrophomonas maltophilia Clarithromycin
# Stenotrophomonas maltophilia Clindamycin
# Stenotrophomonas maltophilia Colistin
# Stenotrophomonas maltophilia ColistinP80
# Stenotrophomonas maltophilia Daptomycin
# Stenotrophomonas maltophilia Doripenem
# Stenotrophomonas maltophilia Ertapenem
# Stenotrophomonas maltophilia Erythromycin
# Stenotrophomonas maltophilia Gentamicin
# Stenotrophomonas maltophilia Imipenem
# Stenotrophomonas maltophilia Levofloxacin
# Stenotrophomonas maltophilia Linezolid
# Stenotrophomonas maltophilia Meropenem
# Stenotrophomonas maltophilia Metronidazole
# Stenotrophomonas maltophilia Minocycline
# Stenotrophomonas maltophilia Moxifloxacin
# Stenotrophomonas maltophilia Oxacillin
# Stenotrophomonas maltophilia Penicillin
# Stenotrophomonas maltophilia Piperacillin tazobactam
# Stenotrophomonas maltophilia Quinupristin dalfopristin
# Stenotrophomonas maltophilia Teicoplanin
# Stenotrophomonas maltophilia Tigecycline
# Stenotrophomonas maltophilia Trimethoprim sulfa
# Stenotrophomonas maltophilia Vancomycin
# Morganella morganii Amikacin
# Morganella morganii Amoxycillin clavulanate
# Morganella morganii Ampicillin
# Morganella morganii Ampicillin sulbactam
# Morganella morganii Azithromycin
# Morganella morganii Aztreonam
# Morganella morganii Aztreonam avibactam
# Morganella morganii Cefepime
# Morganella morganii Cefoxitin
# Morganella morganii Ceftaroline
# Morganella morganii Ceftaroline avibactam
# Morganella morganii Ceftazidime
# Morganella morganii Ceftazidime avibactam
# Morganella morganii Ceftriaxone
# Morganella morganii Clarithromycin
# Morganella morganii Clindamycin
# Morganella morganii Colistin
# Morganella morganii ColistinP80
# Morganella morganii Daptomycin
# Morganella morganii Doripenem
# Morganella morganii Ertapenem
# Morganella morganii Erythromycin
# Morganella morganii Gentamicin
# Morganella morganii Imipenem
# Morganella morganii Levofloxacin
# Morganella morganii Linezolid
# Morganella morganii Meropenem
# Morganella morganii Metronidazole
# Morganella morganii Minocycline
# Morganella morganii Moxifloxacin
# Morganella morganii Oxacillin
# Morganella morganii Penicillin
# Morganella morganii Piperacillin tazobactam
# Morganella morganii Quinupristin dalfopristin
# Morganella morganii Teicoplanin
# Morganella morganii Tigecycline
# Morganella morganii Trimethoprim sulfa
# Morganella morganii Vancomycin
# Acinetobacter pitii Amikacin
# Acinetobacter pitii Amoxycillin clavulanate
# Acinetobacter pitii Ampicillin
# Acinetobacter pitii Ampicillin sulbactam
# Acinetobacter pitii Azithromycin
# Acinetobacter pitii Aztreonam
# Acinetobacter pitii Aztreonam avibactam
# Acinetobacter pitii Cefepime
# Acinetobacter pitii Cefoxitin
# Acinetobacter pitii Ceftaroline
# Acinetobacter pitii Ceftaroline avibactam
# Acinetobacter pitii Ceftazidime
# Acinetobacter pitii Ceftazidime avibactam
# Acinetobacter pitii Ceftriaxone
# Acinetobacter pitii Clarithromycin
# Acinetobacter pitii Clindamycin
# Acinetobacter pitii Colistin
# Acinetobacter pitii ColistinP80
# Acinetobacter pitii Daptomycin
# Acinetobacter pitii Doripenem
# Acinetobacter pitii Ertapenem
# Acinetobacter pitii Erythromycin
# Acinetobacter pitii Gentamicin
# Acinetobacter pitii Imipenem
# Acinetobacter pitii Levofloxacin
# Acinetobacter pitii Linezolid
# Acinetobacter pitii Meropenem
# Acinetobacter pitii Metronidazole
# Acinetobacter pitii Minocycline
# Acinetobacter pitii Moxifloxacin
# Acinetobacter pitii Oxacillin
# Acinetobacter pitii Penicillin
# Acinetobacter pitii Piperacillin tazobactam
# Acinetobacter pitii Quinupristin dalfopristin
# Acinetobacter pitii Teicoplanin
# Acinetobacter pitii Tigecycline
# Acinetobacter pitii Trimethoprim sulfa
# Acinetobacter pitii Vancomycin
# Proteus vulgaris Amikacin
# Proteus vulgaris Amoxycillin clavulanate
# Proteus vulgaris Ampicillin
# Proteus vulgaris Ampicillin sulbactam
# Proteus vulgaris Azithromycin
# Proteus vulgaris Aztreonam
# Proteus vulgaris Aztreonam avibactam
# Proteus vulgaris Cefepime
# Proteus vulgaris Cefoxitin
# Proteus vulgaris Ceftaroline
# Proteus vulgaris Ceftaroline avibactam
# Proteus vulgaris Ceftazidime
# Proteus vulgaris Ceftazidime avibactam
# Proteus vulgaris Ceftriaxone
# Proteus vulgaris Clarithromycin
# Proteus vulgaris Clindamycin
# Proteus vulgaris Colistin
# Proteus vulgaris ColistinP80
# Proteus vulgaris Daptomycin
# Proteus vulgaris Doripenem
# Proteus vulgaris Ertapenem
# Proteus vulgaris Erythromycin
# Proteus vulgaris Gentamicin
# Proteus vulgaris Imipenem
# Proteus vulgaris Levofloxacin
# Proteus vulgaris Linezolid
# Proteus vulgaris Meropenem
# Proteus vulgaris Metronidazole
# Proteus vulgaris Minocycline
# Proteus vulgaris Moxifloxacin
# Proteus vulgaris Oxacillin
# Proteus vulgaris Penicillin
# Proteus vulgaris Piperacillin tazobactam
# Proteus vulgaris Quinupristin dalfopristin
# Proteus vulgaris Teicoplanin
# Proteus vulgaris Tigecycline
# Proteus vulgaris Trimethoprim sulfa
# Proteus vulgaris Vancomycin
# Enterobacter asburiae Amikacin
# Enterobacter asburiae Amoxycillin clavulanate
# Enterobacter asburiae Ampicillin
# Enterobacter asburiae Ampicillin sulbactam
# Enterobacter asburiae Azithromycin
# Enterobacter asburiae Aztreonam
# Enterobacter asburiae Aztreonam avibactam
# Enterobacter asburiae Cefepime
# Enterobacter asburiae Cefoxitin
# Enterobacter asburiae Ceftaroline
# Enterobacter asburiae Ceftaroline avibactam
# Enterobacter asburiae Ceftazidime
# Enterobacter asburiae Ceftazidime avibactam
# Enterobacter asburiae Ceftriaxone
# Enterobacter asburiae Clarithromycin
# Enterobacter asburiae Clindamycin
# Enterobacter asburiae Colistin
# Enterobacter asburiae ColistinP80
# Enterobacter asburiae Daptomycin
# Enterobacter asburiae Doripenem
# Enterobacter asburiae Ertapenem
# Enterobacter asburiae Erythromycin
# Enterobacter asburiae Gentamicin
# Enterobacter asburiae Imipenem
# Enterobacter asburiae Levofloxacin
# Enterobacter asburiae Linezolid
# Enterobacter asburiae Meropenem
# Enterobacter asburiae Metronidazole
# Enterobacter asburiae Minocycline
# Enterobacter asburiae Moxifloxacin
# Enterobacter asburiae Oxacillin
# Enterobacter asburiae Penicillin
# Enterobacter asburiae Piperacillin tazobactam
# Enterobacter asburiae Quinupristin dalfopristin
# Enterobacter asburiae Teicoplanin
# Enterobacter asburiae Tigecycline
# Enterobacter asburiae Trimethoprim sulfa
# Enterobacter asburiae Vancomycin
# Acinetobacter lwoffii Amikacin
# Acinetobacter lwoffii Amoxycillin clavulanate
# Acinetobacter lwoffii Ampicillin
# Acinetobacter lwoffii Ampicillin sulbactam
# Acinetobacter lwoffii Azithromycin
# Acinetobacter lwoffii Aztreonam
# Acinetobacter lwoffii Aztreonam avibactam
# Acinetobacter lwoffii Cefepime
# Acinetobacter lwoffii Cefoxitin
# Acinetobacter lwoffii Ceftaroline
# Acinetobacter lwoffii Ceftaroline avibactam
# Acinetobacter lwoffii Ceftazidime
# Acinetobacter lwoffii Ceftazidime avibactam
# Acinetobacter lwoffii Ceftriaxone
# Acinetobacter lwoffii Clarithromycin
# Acinetobacter lwoffii Clindamycin
# Acinetobacter lwoffii Colistin
# Acinetobacter lwoffii ColistinP80
# Acinetobacter lwoffii Daptomycin
# Acinetobacter lwoffii Doripenem
# Acinetobacter lwoffii Ertapenem
# Acinetobacter lwoffii Erythromycin
# Acinetobacter lwoffii Gentamicin
# Acinetobacter lwoffii Imipenem
# Acinetobacter lwoffii Levofloxacin
# Acinetobacter lwoffii Linezolid
# Acinetobacter lwoffii Meropenem
# Acinetobacter lwoffii Metronidazole
# Acinetobacter lwoffii Minocycline
# Acinetobacter lwoffii Moxifloxacin
# Acinetobacter lwoffii Oxacillin
# Acinetobacter lwoffii Penicillin
# Acinetobacter lwoffii Piperacillin tazobactam
# Acinetobacter lwoffii Quinupristin dalfopristin
# Acinetobacter lwoffii Teicoplanin
# Acinetobacter lwoffii Tigecycline
# Acinetobacter lwoffii Trimethoprim sulfa
# Acinetobacter lwoffii Vancomycin
# Streptococcus dysgalactiae Amikacin
# Streptococcus dysgalactiae Amoxycillin clavulanate
# Streptococcus dysgalactiae Ampicillin
# Streptococcus dysgalactiae Ampicillin sulbactam
# Streptococcus dysgalactiae Azithromycin
# Streptococcus dysgalactiae Aztreonam
# Streptococcus dysgalactiae Aztreonam avibactam
# Streptococcus dysgalactiae Cefepime
# Streptococcus dysgalactiae Cefoxitin
# Streptococcus dysgalactiae Ceftaroline
# Streptococcus dysgalactiae Ceftaroline avibactam
# Streptococcus dysgalactiae Ceftazidime
# Streptococcus dysgalactiae Ceftazidime avibactam
# Streptococcus dysgalactiae Ceftriaxone
# Streptococcus dysgalactiae Clarithromycin
# Streptococcus dysgalactiae Clindamycin
# Streptococcus dysgalactiae Colistin
# Streptococcus dysgalactiae ColistinP80
# Streptococcus dysgalactiae Daptomycin
# Streptococcus dysgalactiae Doripenem
# Streptococcus dysgalactiae Ertapenem
# Streptococcus dysgalactiae Erythromycin
# Streptococcus dysgalactiae Gentamicin
# Streptococcus dysgalactiae Imipenem
# Streptococcus dysgalactiae Levofloxacin
# Streptococcus dysgalactiae Linezolid
# Streptococcus dysgalactiae Meropenem
# Streptococcus dysgalactiae Metronidazole
# Streptococcus dysgalactiae Minocycline
# Streptococcus dysgalactiae Moxifloxacin
# Streptococcus dysgalactiae Oxacillin
# Streptococcus dysgalactiae Penicillin
# Streptococcus dysgalactiae Piperacillin tazobactam
# Streptococcus dysgalactiae Quinupristin dalfopristin
# Streptococcus dysgalactiae Teicoplanin
# Streptococcus dysgalactiae Tigecycline
# Streptococcus dysgalactiae Trimethoprim sulfa
# Streptococcus dysgalactiae Vancomycin
# Clostridioides (Clostridium) difficile Amikacin
# Clostridioides (Clostridium) difficile Amoxycillin clavulanate
# Clostridioides (Clostridium) difficile Ampicillin
# Clostridioides (Clostridium) difficile Ampicillin sulbactam
# Clostridioides (Clostridium) difficile Azithromycin
# Clostridioides (Clostridium) difficile Aztreonam
# Clostridioides (Clostridium) difficile Aztreonam avibactam
# Clostridioides (Clostridium) difficile Cefepime
# Clostridioides (Clostridium) difficile Cefoxitin
# Clostridioides (Clostridium) difficile Ceftaroline
# Clostridioides (Clostridium) difficile Ceftaroline avibactam
# Clostridioides (Clostridium) difficile Ceftazidime
# Clostridioides (Clostridium) difficile Ceftazidime avibactam
# Clostridioides (Clostridium) difficile Ceftriaxone
# Clostridioides (Clostridium) difficile Clarithromycin
# Clostridioides (Clostridium) difficile Clindamycin
# Clostridioides (Clostridium) difficile Colistin
# Clostridioides (Clostridium) difficile ColistinP80
# Clostridioides (Clostridium) difficile Daptomycin
# Clostridioides (Clostridium) difficile Doripenem
# Clostridioides (Clostridium) difficile Ertapenem
# Clostridioides (Clostridium) difficile Erythromycin
# Clostridioides (Clostridium) difficile Gentamicin
# Clostridioides (Clostridium) difficile Imipenem
# Clostridioides (Clostridium) difficile Levofloxacin
# Clostridioides (Clostridium) difficile Linezolid
# Clostridioides (Clostridium) difficile Meropenem
# Clostridioides (Clostridium) difficile Metronidazole
# Clostridioides (Clostridium) difficile Minocycline
# Clostridioides (Clostridium) difficile Moxifloxacin
# Clostridioides (Clostridium) difficile Oxacillin
# Clostridioides (Clostridium) difficile Penicillin
# Clostridioides (Clostridium) difficile Piperacillin tazobactam
# Clostridioides (Clostridium) difficile Quinupristin dalfopristin
# Clostridioides (Clostridium) difficile Teicoplanin
# Clostridioides (Clostridium) difficile Tigecycline
# Clostridioides (Clostridium) difficile Trimethoprim sulfa
# Clostridioides (Clostridium) difficile Vancomycin
# Clostridium perfringens Amikacin
# Clostridium perfringens Amoxycillin clavulanate
# Clostridium perfringens Ampicillin
# Clostridium perfringens Ampicillin sulbactam
# Clostridium perfringens Azithromycin
# Clostridium perfringens Aztreonam
# Clostridium perfringens Aztreonam avibactam
# Clostridium perfringens Cefepime
# Clostridium perfringens Cefoxitin
# Clostridium perfringens Ceftaroline
# Clostridium perfringens Ceftaroline avibactam
# Clostridium perfringens Ceftazidime
# Clostridium perfringens Ceftazidime avibactam
# Clostridium perfringens Ceftriaxone
# Clostridium perfringens Clarithromycin
# Clostridium perfringens Clindamycin
# Clostridium perfringens Colistin
# Clostridium perfringens ColistinP80
# Clostridium perfringens Daptomycin
# Clostridium perfringens Doripenem
# Clostridium perfringens Ertapenem
# Clostridium perfringens Erythromycin
# Clostridium perfringens Gentamicin
# Clostridium perfringens Imipenem
# Clostridium perfringens Levofloxacin
# Clostridium perfringens Linezolid
# Clostridium perfringens Meropenem
# Clostridium perfringens Metronidazole
# Clostridium perfringens Minocycline
# Clostridium perfringens Moxifloxacin
# Clostridium perfringens Oxacillin
# Clostridium perfringens Penicillin
# Clostridium perfringens Piperacillin tazobactam
# Clostridium perfringens Quinupristin dalfopristin
# Clostridium perfringens Teicoplanin
# Clostridium perfringens Tigecycline
# Clostridium perfringens Trimethoprim sulfa
# Clostridium perfringens Vancomycin
# Staphylococcus hominis Amikacin
# Staphylococcus hominis Amoxycillin clavulanate
# Staphylococcus hominis Ampicillin
# Staphylococcus hominis Ampicillin sulbactam
# Staphylococcus hominis Azithromycin
# Staphylococcus hominis Aztreonam
# Staphylococcus hominis Aztreonam avibactam
# Staphylococcus hominis Cefepime
# Staphylococcus hominis Cefoxitin
# Staphylococcus hominis Ceftaroline
# Staphylococcus hominis Ceftaroline avibactam
# Staphylococcus hominis Ceftazidime
# Staphylococcus hominis Ceftazidime avibactam
# Staphylococcus hominis Ceftriaxone
# Staphylococcus hominis Clarithromycin
# Staphylococcus hominis Clindamycin
# Staphylococcus hominis Colistin
# Staphylococcus hominis ColistinP80
# Staphylococcus hominis Daptomycin
# Staphylococcus hominis Doripenem
# Staphylococcus hominis Ertapenem
# Staphylococcus hominis Erythromycin
# Staphylococcus hominis Gentamicin
# Staphylococcus hominis Imipenem
# Staphylococcus hominis Levofloxacin
# Staphylococcus hominis Linezolid
# Staphylococcus hominis Meropenem
# Staphylococcus hominis Metronidazole
# Staphylococcus hominis Minocycline
# Staphylococcus hominis Moxifloxacin
# Staphylococcus hominis Oxacillin
# Staphylococcus hominis Penicillin
# Staphylococcus hominis Piperacillin tazobactam
# Staphylococcus hominis Quinupristin dalfopristin
# Staphylococcus hominis Teicoplanin
# Staphylococcus hominis Tigecycline
# Staphylococcus hominis Trimethoprim sulfa
# Staphylococcus hominis Vancomycin
# Moraxella catarrhalis Amikacin
# Moraxella catarrhalis Amoxycillin clavulanate
# Moraxella catarrhalis Ampicillin
# Moraxella catarrhalis Ampicillin sulbactam
# Moraxella catarrhalis Azithromycin
# Moraxella catarrhalis Aztreonam
# Moraxella catarrhalis Aztreonam avibactam
# Moraxella catarrhalis Cefepime
# Moraxella catarrhalis Cefoxitin
# Moraxella catarrhalis Ceftaroline
# Moraxella catarrhalis Ceftaroline avibactam
# Moraxella catarrhalis Ceftazidime
# Moraxella catarrhalis Ceftazidime avibactam
# Moraxella catarrhalis Ceftriaxone
# Moraxella catarrhalis Clarithromycin
# Moraxella catarrhalis Clindamycin
# Moraxella catarrhalis Colistin
# Moraxella catarrhalis ColistinP80
# Moraxella catarrhalis Daptomycin
# Moraxella catarrhalis Doripenem
# Moraxella catarrhalis Ertapenem
# Moraxella catarrhalis Erythromycin
# Moraxella catarrhalis Gentamicin
# Moraxella catarrhalis Imipenem
# Moraxella catarrhalis Levofloxacin
# Moraxella catarrhalis Linezolid
# Moraxella catarrhalis Meropenem
# Moraxella catarrhalis Metronidazole
# Moraxella catarrhalis Minocycline
# Moraxella catarrhalis Moxifloxacin
# Moraxella catarrhalis Oxacillin
# Moraxella catarrhalis Penicillin
# Moraxella catarrhalis Piperacillin tazobactam
# Moraxella catarrhalis Quinupristin dalfopristin
# Moraxella catarrhalis Teicoplanin
# Moraxella catarrhalis Tigecycline
# Moraxella catarrhalis Trimethoprim sulfa
# Moraxella catarrhalis Vancomycin
# Klebsiella variicola Amikacin
# Klebsiella variicola Amoxycillin clavulanate
# Klebsiella variicola Ampicillin
# Klebsiella variicola Ampicillin sulbactam
# Klebsiella variicola Azithromycin
# Klebsiella variicola Aztreonam
# Klebsiella variicola Aztreonam avibactam
# Klebsiella variicola Cefepime
# Klebsiella variicola Cefoxitin
# Klebsiella variicola Ceftaroline
# Klebsiella variicola Ceftaroline avibactam
# Klebsiella variicola Ceftazidime
# Klebsiella variicola Ceftazidime avibactam
# Klebsiella variicola Ceftriaxone
# Klebsiella variicola Clarithromycin
# Klebsiella variicola Clindamycin
# Klebsiella variicola Colistin
# Klebsiella variicola ColistinP80
# Klebsiella variicola Daptomycin
# Klebsiella variicola Doripenem
# Klebsiella variicola Ertapenem
# Klebsiella variicola Erythromycin
# Klebsiella variicola Gentamicin
# Klebsiella variicola Imipenem
# Klebsiella variicola Levofloxacin
# Klebsiella variicola Linezolid
# Klebsiella variicola Meropenem
# Klebsiella variicola Metronidazole
# Klebsiella variicola Minocycline
# Klebsiella variicola Moxifloxacin
# Klebsiella variicola Oxacillin
# Klebsiella variicola Penicillin
# Klebsiella variicola Piperacillin tazobactam
# Klebsiella variicola Quinupristin dalfopristin
# Klebsiella variicola Teicoplanin
# Klebsiella variicola Tigecycline
# Klebsiella variicola Trimethoprim sulfa
# Klebsiella variicola Vancomycin
# Streptococcus anginosus Amikacin
# Streptococcus anginosus Amoxycillin clavulanate
# Streptococcus anginosus Ampicillin
# Streptococcus anginosus Ampicillin sulbactam
# Streptococcus anginosus Azithromycin
# Streptococcus anginosus Aztreonam
# Streptococcus anginosus Aztreonam avibactam
# Streptococcus anginosus Cefepime
# Streptococcus anginosus Cefoxitin
# Streptococcus anginosus Ceftaroline
# Streptococcus anginosus Ceftaroline avibactam
# Streptococcus anginosus Ceftazidime
# Streptococcus anginosus Ceftazidime avibactam
# Streptococcus anginosus Ceftriaxone
# Streptococcus anginosus Clarithromycin
# Streptococcus anginosus Clindamycin
# Streptococcus anginosus Colistin
# Streptococcus anginosus ColistinP80
# Streptococcus anginosus Daptomycin
# Streptococcus anginosus Doripenem
# Streptococcus anginosus Ertapenem
# Streptococcus anginosus Erythromycin
# Streptococcus anginosus Gentamicin
# Streptococcus anginosus Imipenem
# Streptococcus anginosus Levofloxacin
# Streptococcus anginosus Linezolid
# Streptococcus anginosus Meropenem
# Streptococcus anginosus Metronidazole
# Streptococcus anginosus Minocycline
# Streptococcus anginosus Moxifloxacin
# Streptococcus anginosus Oxacillin
# Streptococcus anginosus Penicillin
# Streptococcus anginosus Piperacillin tazobactam
# Streptococcus anginosus Quinupristin dalfopristin
# Streptococcus anginosus Teicoplanin
# Streptococcus anginosus Tigecycline
# Streptococcus anginosus Trimethoprim sulfa
# Streptococcus anginosus Vancomycin
# Enterobacter kobei Amikacin
# Enterobacter kobei Amoxycillin clavulanate
# Enterobacter kobei Ampicillin
# Enterobacter kobei Ampicillin sulbactam
# Enterobacter kobei Azithromycin
# Enterobacter kobei Aztreonam
# Enterobacter kobei Aztreonam avibactam
# Enterobacter kobei Cefepime
# Enterobacter kobei Cefoxitin
# Enterobacter kobei Ceftaroline
# Enterobacter kobei Ceftaroline avibactam
# Enterobacter kobei Ceftazidime
# Enterobacter kobei Ceftazidime avibactam
# Enterobacter kobei Ceftriaxone
# Enterobacter kobei Clarithromycin
# Enterobacter kobei Clindamycin
# Enterobacter kobei Colistin
# Enterobacter kobei ColistinP80
# Enterobacter kobei Daptomycin
# Enterobacter kobei Doripenem
# Enterobacter kobei Ertapenem
# Enterobacter kobei Erythromycin
# Enterobacter kobei Gentamicin
# Enterobacter kobei Imipenem
# Enterobacter kobei Levofloxacin
# Enterobacter kobei Linezolid
# Enterobacter kobei Meropenem
# Enterobacter kobei Metronidazole
# Enterobacter kobei Minocycline
# Enterobacter kobei Moxifloxacin
# Enterobacter kobei Oxacillin
# Enterobacter kobei Penicillin
# Enterobacter kobei Piperacillin tazobactam
# Enterobacter kobei Quinupristin dalfopristin
# Enterobacter kobei Teicoplanin
# Enterobacter kobei Tigecycline
# Enterobacter kobei Trimethoprim sulfa
# Enterobacter kobei Vancomycin
# Parvimonas micra Amikacin
# Parvimonas micra Amoxycillin clavulanate
# Parvimonas micra Ampicillin
# Parvimonas micra Ampicillin sulbactam
# Parvimonas micra Azithromycin
# Parvimonas micra Aztreonam
# Parvimonas micra Aztreonam avibactam
# Parvimonas micra Cefepime
# Parvimonas micra Cefoxitin
# Parvimonas micra Ceftaroline
# Parvimonas micra Ceftaroline avibactam
# Parvimonas micra Ceftazidime
# Parvimonas micra Ceftazidime avibactam
# Parvimonas micra Ceftriaxone
# Parvimonas micra Clarithromycin
# Parvimonas micra Clindamycin
# Parvimonas micra Colistin
# Parvimonas micra ColistinP80
# Parvimonas micra Daptomycin
# Parvimonas micra Doripenem
# Parvimonas micra Ertapenem
# Parvimonas micra Erythromycin
# Parvimonas micra Gentamicin
# Parvimonas micra Imipenem
# Parvimonas micra Levofloxacin
# Parvimonas micra Linezolid
# Parvimonas micra Meropenem
# Parvimonas micra Metronidazole
# Parvimonas micra Minocycline
# Parvimonas micra Moxifloxacin
# Parvimonas micra Oxacillin
# Parvimonas micra Penicillin
# Parvimonas micra Piperacillin tazobactam
# Parvimonas micra Quinupristin dalfopristin
# Parvimonas micra Teicoplanin
# Parvimonas micra Tigecycline
# Parvimonas micra Trimethoprim sulfa
# Parvimonas micra Vancomycin
# Prevotella bivia Amikacin
# Prevotella bivia Amoxycillin clavulanate
# Prevotella bivia Ampicillin
# Prevotella bivia Ampicillin sulbactam
# Prevotella bivia Azithromycin
# Prevotella bivia Aztreonam
# Prevotella bivia Aztreonam avibactam
# Prevotella bivia Cefepime
# Prevotella bivia Cefoxitin
# Prevotella bivia Ceftaroline
# Prevotella bivia Ceftaroline avibactam
# Prevotella bivia Ceftazidime
# Prevotella bivia Ceftazidime avibactam
# Prevotella bivia Ceftriaxone
# Prevotella bivia Clarithromycin
# Prevotella bivia Clindamycin
# Prevotella bivia Colistin
# Prevotella bivia ColistinP80
# Prevotella bivia Daptomycin
# Prevotella bivia Doripenem
# Prevotella bivia Ertapenem
# Prevotella bivia Erythromycin
# Prevotella bivia Gentamicin
# Prevotella bivia Imipenem
# Prevotella bivia Levofloxacin
# Prevotella bivia Linezolid
# Prevotella bivia Meropenem
# Prevotella bivia Metronidazole
# Prevotella bivia Minocycline
# Prevotella bivia Moxifloxacin
# Prevotella bivia Oxacillin
# Prevotella bivia Penicillin
# Prevotella bivia Piperacillin tazobactam
# Prevotella bivia Quinupristin dalfopristin
# Prevotella bivia Teicoplanin
# Prevotella bivia Tigecycline
# Prevotella bivia Trimethoprim sulfa
# Prevotella bivia Vancomycin
# Providencia stuartii Amikacin
# Providencia stuartii Amoxycillin clavulanate
# Providencia stuartii Ampicillin
# Providencia stuartii Ampicillin sulbactam
# Providencia stuartii Azithromycin
# Providencia stuartii Aztreonam
# Providencia stuartii Aztreonam avibactam
# Providencia stuartii Cefepime
# Providencia stuartii Cefoxitin
# Providencia stuartii Ceftaroline
# Providencia stuartii Ceftaroline avibactam
# Providencia stuartii Ceftazidime
# Providencia stuartii Ceftazidime avibactam
# Providencia stuartii Ceftriaxone
# Providencia stuartii Clarithromycin
# Providencia stuartii Clindamycin
# Providencia stuartii Colistin
# Providencia stuartii ColistinP80
# Providencia stuartii Daptomycin
# Providencia stuartii Doripenem
# Providencia stuartii Ertapenem
# Providencia stuartii Erythromycin
# Providencia stuartii Gentamicin
# Providencia stuartii Imipenem
# Providencia stuartii Levofloxacin
# Providencia stuartii Linezolid
# Providencia stuartii Meropenem
# Providencia stuartii Metronidazole
# Providencia stuartii Minocycline
# Providencia stuartii Moxifloxacin
# Providencia stuartii Oxacillin
# Providencia stuartii Penicillin
# Providencia stuartii Piperacillin tazobactam
# Providencia stuartii Quinupristin dalfopristin
# Providencia stuartii Teicoplanin
# Providencia stuartii Tigecycline
# Providencia stuartii Trimethoprim sulfa
# Providencia stuartii Vancomycin
# Staphylococcus lugdunensis Amikacin
# Staphylococcus lugdunensis Amoxycillin clavulanate
# Staphylococcus lugdunensis Ampicillin
# Staphylococcus lugdunensis Ampicillin sulbactam
# Staphylococcus lugdunensis Azithromycin
# Staphylococcus lugdunensis Aztreonam
# Staphylococcus lugdunensis Aztreonam avibactam
# Staphylococcus lugdunensis Cefepime
# Staphylococcus lugdunensis Cefoxitin
# Staphylococcus lugdunensis Ceftaroline
# Staphylococcus lugdunensis Ceftaroline avibactam
# Staphylococcus lugdunensis Ceftazidime
# Staphylococcus lugdunensis Ceftazidime avibactam
# Staphylococcus lugdunensis Ceftriaxone
# Staphylococcus lugdunensis Clarithromycin
# Staphylococcus lugdunensis Clindamycin
# Staphylococcus lugdunensis Colistin
# Staphylococcus lugdunensis ColistinP80
# Staphylococcus lugdunensis Daptomycin
# Staphylococcus lugdunensis Doripenem
# Staphylococcus lugdunensis Ertapenem
# Staphylococcus lugdunensis Erythromycin
# Staphylococcus lugdunensis Gentamicin
# Staphylococcus lugdunensis Imipenem
# Staphylococcus lugdunensis Levofloxacin
# Staphylococcus lugdunensis Linezolid
# Staphylococcus lugdunensis Meropenem
# Staphylococcus lugdunensis Metronidazole
# Staphylococcus lugdunensis Minocycline
# Staphylococcus lugdunensis Moxifloxacin
# Staphylococcus lugdunensis Oxacillin
# Staphylococcus lugdunensis Penicillin
# Staphylococcus lugdunensis Piperacillin tazobactam
# Staphylococcus lugdunensis Quinupristin dalfopristin
# Staphylococcus lugdunensis Teicoplanin
# Staphylococcus lugdunensis Tigecycline
# Staphylococcus lugdunensis Trimethoprim sulfa
# Staphylococcus lugdunensis Vancomycin
# Bacteroides thetaiotaomicron Amikacin
# Bacteroides thetaiotaomicron Amoxycillin clavulanate
# Bacteroides thetaiotaomicron Ampicillin
# Bacteroides thetaiotaomicron Ampicillin sulbactam
# Bacteroides thetaiotaomicron Azithromycin
# Bacteroides thetaiotaomicron Aztreonam
# Bacteroides thetaiotaomicron Aztreonam avibactam
# Bacteroides thetaiotaomicron Cefepime
# Bacteroides thetaiotaomicron Cefoxitin
# Bacteroides thetaiotaomicron Ceftaroline
# Bacteroides thetaiotaomicron Ceftaroline avibactam
# Bacteroides thetaiotaomicron Ceftazidime
# Bacteroides thetaiotaomicron Ceftazidime avibactam
# Bacteroides thetaiotaomicron Ceftriaxone
# Bacteroides thetaiotaomicron Clarithromycin
# Bacteroides thetaiotaomicron Clindamycin
# Bacteroides thetaiotaomicron Colistin
# Bacteroides thetaiotaomicron ColistinP80
# Bacteroides thetaiotaomicron Daptomycin
# Bacteroides thetaiotaomicron Doripenem
# Bacteroides thetaiotaomicron Ertapenem
# Bacteroides thetaiotaomicron Erythromycin
# Bacteroides thetaiotaomicron Gentamicin
# Bacteroides thetaiotaomicron Imipenem
# Bacteroides thetaiotaomicron Levofloxacin
# Bacteroides thetaiotaomicron Linezolid
# Bacteroides thetaiotaomicron Meropenem
# Bacteroides thetaiotaomicron Metronidazole
# Bacteroides thetaiotaomicron Minocycline
# Bacteroides thetaiotaomicron Moxifloxacin
# Bacteroides thetaiotaomicron Oxacillin
# Bacteroides thetaiotaomicron Penicillin
# Bacteroides thetaiotaomicron Piperacillin tazobactam
# Bacteroides thetaiotaomicron Quinupristin dalfopristin
# Bacteroides thetaiotaomicron Teicoplanin
# Bacteroides thetaiotaomicron Tigecycline
# Bacteroides thetaiotaomicron Trimethoprim sulfa
# Bacteroides thetaiotaomicron Vancomycin
# Peptostreptococcus magnus Amikacin
# Peptostreptococcus magnus Amoxycillin clavulanate
# Peptostreptococcus magnus Ampicillin
# Peptostreptococcus magnus Ampicillin sulbactam
# Peptostreptococcus magnus Azithromycin
# Peptostreptococcus magnus Aztreonam
# Peptostreptococcus magnus Aztreonam avibactam
# Peptostreptococcus magnus Cefepime
# Peptostreptococcus magnus Cefoxitin
# Peptostreptococcus magnus Ceftaroline
# Peptostreptococcus magnus Ceftaroline avibactam
# Peptostreptococcus magnus Ceftazidime
# Peptostreptococcus magnus Ceftazidime avibactam
# Peptostreptococcus magnus Ceftriaxone
# Peptostreptococcus magnus Clarithromycin
# Peptostreptococcus magnus Clindamycin
# Peptostreptococcus magnus Colistin
# Peptostreptococcus magnus ColistinP80
# Peptostreptococcus magnus Daptomycin
# Peptostreptococcus magnus Doripenem
# Peptostreptococcus magnus Ertapenem
# Peptostreptococcus magnus Erythromycin
# Peptostreptococcus magnus Gentamicin
# Peptostreptococcus magnus Imipenem
# Peptostreptococcus magnus Levofloxacin
# Peptostreptococcus magnus Linezolid
# Peptostreptococcus magnus Meropenem
# Peptostreptococcus magnus Metronidazole
# Peptostreptococcus magnus Minocycline
# Peptostreptococcus magnus Moxifloxacin
# Peptostreptococcus magnus Oxacillin
# Peptostreptococcus magnus Penicillin
# Peptostreptococcus magnus Piperacillin tazobactam
# Peptostreptococcus magnus Quinupristin dalfopristin
# Peptostreptococcus magnus Teicoplanin
# Peptostreptococcus magnus Tigecycline
# Peptostreptococcus magnus Trimethoprim sulfa
# Peptostreptococcus magnus Vancomycin
# Serratia liquefaciens Amikacin
# Serratia liquefaciens Amoxycillin clavulanate
# Serratia liquefaciens Ampicillin
# Serratia liquefaciens Ampicillin sulbactam
# Serratia liquefaciens Azithromycin
# Serratia liquefaciens Aztreonam
# Serratia liquefaciens Aztreonam avibactam
# Serratia liquefaciens Cefepime
# Serratia liquefaciens Cefoxitin
# Serratia liquefaciens Ceftaroline
# Serratia liquefaciens Ceftaroline avibactam
# Serratia liquefaciens Ceftazidime
# Serratia liquefaciens Ceftazidime avibactam
# Serratia liquefaciens Ceftriaxone
# Serratia liquefaciens Clarithromycin
# Serratia liquefaciens Clindamycin
# Serratia liquefaciens Colistin
# Serratia liquefaciens ColistinP80
# Serratia liquefaciens Daptomycin
# Serratia liquefaciens Doripenem
# Serratia liquefaciens Ertapenem
# Serratia liquefaciens Erythromycin
# Serratia liquefaciens Gentamicin
# Serratia liquefaciens Imipenem
# Serratia liquefaciens Levofloxacin
# Serratia liquefaciens Linezolid
# Serratia liquefaciens Meropenem
# Serratia liquefaciens Metronidazole
# Serratia liquefaciens Minocycline
# Serratia liquefaciens Moxifloxacin
# Serratia liquefaciens Oxacillin
# Serratia liquefaciens Penicillin
# Serratia liquefaciens Piperacillin tazobactam
# Serratia liquefaciens Quinupristin dalfopristin
# Serratia liquefaciens Teicoplanin
# Serratia liquefaciens Tigecycline
# Serratia liquefaciens Trimethoprim sulfa
# Serratia liquefaciens Vancomycin
# Acinetobacter nosocomialis Amikacin
# Acinetobacter nosocomialis Amoxycillin clavulanate
# Acinetobacter nosocomialis Ampicillin
# Acinetobacter nosocomialis Ampicillin sulbactam
# Acinetobacter nosocomialis Azithromycin
# Acinetobacter nosocomialis Aztreonam
# Acinetobacter nosocomialis Aztreonam avibactam
# Acinetobacter nosocomialis Cefepime
# Acinetobacter nosocomialis Cefoxitin
# Acinetobacter nosocomialis Ceftaroline
# Acinetobacter nosocomialis Ceftaroline avibactam
# Acinetobacter nosocomialis Ceftazidime
# Acinetobacter nosocomialis Ceftazidime avibactam
# Acinetobacter nosocomialis Ceftriaxone
# Acinetobacter nosocomialis Clarithromycin
# Acinetobacter nosocomialis Clindamycin
# Acinetobacter nosocomialis Colistin
# Acinetobacter nosocomialis ColistinP80
# Acinetobacter nosocomialis Daptomycin
# Acinetobacter nosocomialis Doripenem
# Acinetobacter nosocomialis Ertapenem
# Acinetobacter nosocomialis Erythromycin
# Acinetobacter nosocomialis Gentamicin
# Acinetobacter nosocomialis Imipenem
# Acinetobacter nosocomialis Levofloxacin
# Acinetobacter nosocomialis Linezolid
# Acinetobacter nosocomialis Meropenem
# Acinetobacter nosocomialis Metronidazole
# Acinetobacter nosocomialis Minocycline
# Acinetobacter nosocomialis Moxifloxacin
# Acinetobacter nosocomialis Oxacillin
# Acinetobacter nosocomialis Penicillin
# Acinetobacter nosocomialis Piperacillin tazobactam
# Acinetobacter nosocomialis Quinupristin dalfopristin
# Acinetobacter nosocomialis Teicoplanin
# Acinetobacter nosocomialis Tigecycline
# Acinetobacter nosocomialis Trimethoprim sulfa
# Acinetobacter nosocomialis Vancomycin

# %% [markdown]
# # RCLUSTER VALUES

# %%
DF, pL, bP, drugs=read_dataset('test')
newDF=resistant_cluster_values(DF, pL, bP, drugs)
newDF.to_csv('results/Rcluster/resistant_cluster_values_test.csv', index=False, float_format='%.6f')

DF, pL, bP, drugs=read_dataset('inform')
newDF=resistant_cluster_values(DF, pL, bP, drugs)
newDF.to_csv('results/Rcluster/resistant_cluster_values_inform.csv', index=False, float_format='%.6f')

# %% [markdown]
# # DIFFERENCE BETWEEN TEST AND INFORM
#
# Data for Fig 7, Supp Figs 10 and 22

# %%
DFT=pd.read_csv('results/Rcluster/resistant_cluster_values_test.csv')
DFI=pd.read_csv('results/Rcluster/resistant_cluster_values_inform.csv')
YL=range(2012,2018)
L=[]
for index, row in DFT.iterrows():
    sp=row['Species']
    dr=row['Antibiotic']
    row2=DFI[(DFI.Species==sp) &(DFI.Antibiotic==dr)]
    if row2.empty: continue
    Diff=0
    for y in YL:
        r='R'+str(y)
        s='S'+str(y)
        
        #DIFFERENCE IN R
        if pd.isna(row[r]) or pd.isna(row2[r].mean()):#no R cluster in either (no data to compare)
            continue
        #DIFFERENCE IN S
        if pd.isna(row[s]):#no S cluster in TEST
            if pd.isna(row2[s].mean()):#no S cluster in either
                Diff+=(row[r]-row2[r].mean())**2
                print(r,'Diff1', (row[r]-row2[r].mean())**2)
            else:#no S cluster in TEST, but yes in INFORM
                avg=(row2[s]+row2[r])/2
                Diff+=(avg.mean()-row[r])**2
                print(s,'Diff2',(avg.mean()-row[r])**2)
        elif pd.isna(row2[s].mean()):#no S cluster in INFORM, but yes in TEST
            avg=(row[s]+row[r])/2
            Diff+=(avg-row2[r].mean())**2
            print(s,'Diff3',(avg-row2[r])**2)
        else:#R and S cluster in both
            Diff+=(row[r]-row2[r].mean())**2
            Diff+=(row[s]-row2[s].mean())**2
            print(s,'Diff4',(row[s]-row2[s].mean())**2)
    Diff/=len(YL)
    L.append([sp,dr,Diff])

L=sorted(L, reverse=True, key=itemgetter(2))
newDF=pd.DataFrame.from_records(L, columns=['Species', 'Antibiotic', 'Diff'])
newDF.to_csv('results/Rcluster/resistant_cluster_values_test_vs_inform.csv', index=False, float_format='%.6f')

# %% [markdown]
# # DATAPOINTS FOR CAZ AVI TESTING
#
# Data for Supp Fig 6

# %%
TEST=DF[DF.Study=='TEST']
INFORM=DF[DF.Study=='Inform']

T=[]
for dr in drugs:
    newDF=pd.DataFrame({'Year': DF['Year'], dr: DF[dr]})
    newDF=newDF.dropna()
    yL=get_key(newDF,'Year')
    Data=[]
    for y in yL:
        DFy=newDF[newDF.Year==y]
        v=len(DFy)
        T.append([dr,y,v])
DFT=pd.DataFrame.from_records(T, columns=['Antibiotic','Year','Datapoints'])
DFT.to_csv('data/drug_testing_atlas.csv', index=False)

T=[]
for dr in drugs:
    newDF=pd.DataFrame({'Year': TEST['Year'], dr: TEST[dr]})
    newDF=newDF.dropna()
    yL=get_key(newDF,'Year')
    Data=[]
    for y in yL:
        DFy=newDF[newDF.Year==y]
        v=len(DFy)
        T.append([dr,y,v])
DFT=pd.DataFrame.from_records(T, columns=['Antibiotic','Year','Datapoints'])
DFT.to_csv('data/drug_testing_test.csv', index=False)

T=[]
for dr in drugs:
    newDF=pd.DataFrame({'Year': INFORM['Year'], dr: INFORM[dr]})
    newDF=newDF.dropna()
    yL=get_key(newDF,'Year')
    Data=[]
    for y in yL:
        DFy=newDF[newDF.Year==y]
        v=len(DFy)
        T.append([dr,y,v])
DFT=pd.DataFrame.from_records(T, columns=['Antibiotic','Year','Datapoints'])
DFT.to_csv('data/drug_testing_inform.csv', index=False)

# %% [markdown]
# # PA PAIRS WITH LOW TAU (Uncertain)
# Data for Supp Fig 12

# %%
DFdist=pd.read_csv('results/correlations/tau_test.csv')
Diff=pd.read_csv('results/Rcluster/resistant_cluster_values_test_vs_inform.csv')
SS=pd.read_csv('data/average_mic_per_year_complete.csv')

SN=[]
SV=[]
SM=[]
SD=[]
for index,row in DFdist.iterrows():
    sp=row['Species']
    dr=row['Antibiotic']
    SSsp=SS[(SS.Species==sp) & (SS.Antibiotic==dr)]
    N=SSsp['Number of cases'].mean()
    V=SSsp['Number of cases'].std()
    M=SSsp['Number of cases'].min()
    SN.append(N)
    SV.append(V)
    SM.append(M)
    Diffsp=Diff[(Diff.Species==sp) & (Diff.Antibiotic==dr)]
    if Diffsp.empty: continue
    D=Diffsp['Diff'].mean()
    SD.append(D)
SN=np.array(SN)
SV=np.array(SV)
SM=np.array(SM)
SD=np.array(SD)
N1=np.quantile(SN,0.25)
V1=np.quantile(SV,0.75)
M1=np.quantile(SM,0.25)
D1=np.quantile(SD,0.75)

DFdist=DFdist[DFdist.Tau<0.25]
print(len(DFdist))
DFdist=DFdist.iloc[::-1]
DFdist=DFdist.reset_index(drop=True)
List=[]
for index,row in DFdist.iterrows():
    sp=row['Species']
    dr=row['Antibiotic']
    tau=row['Tau']
    L='('
    #check if sample size issue
    SSsp=SS[(SS.Species==sp) & (SS.Antibiotic==dr)]
    N=SSsp['Number of cases'].mean()
    V=SSsp['Number of cases'].std()
    M=SSsp['Number of cases'].min()
    if N<N1:
        L+='N'
        Ns+=1
    if V>V1:
        L+='V'
        Nv+=1
    if M<M1:
        L+='M'
        Nm+=1
    #check if data curation issue
    Diffsp=Diff[(Diff.Species==sp) & (Diff.Antibiotic==dr)]
    D=Diffsp['Diff'].mean()
    if D>D1:
        L+='D'
        Nd+=1
    L+=')'
    if L=='()':
        L='(U)'
        Nu+=1
        List.append([sp,dr,tau,N,V,M,D])
newDF=pd.DataFrame.from_records(List, columns=['Species','Antibiotic','Tau','N','V','M','D'])
newDF.to_csv('results/correlations/bad_correlations.csv', index=False, float_format='%.3f')

# %% [markdown]
# # MOVING BREAKPOINTS
#
# Data for Supp Fig 13

# %%
L=[]
pC=get_key(DF,'Country')
BP=pd.read_excel('data/breakpoints_year.xls')
pLnew=get_key(BP,'Species')
for country in pC:#for every country
    DFc=DF[DF.Country==country]
    if DFc.empty: continue   
    for sp in pLnew:#for every pathogen
        DFsp=DFc[DFc.Species==sp]
        if DFsp.empty: continue
        BPsp=BP[BP.Species==sp]
        for dr in drugs:#for every drug
            BPdr=BPsp[BPsp.Antibiotic==dr]
            if BPdr.empty: continue
            DFnew=pd.DataFrame({'Year': DFsp['Year'], dr: DFsp[dr]})
            DFnew=DFnew.dropna()
            yL=get_key(DFnew, 'Year')
            for y in yL:#for every year
                DFy=DFnew[DFnew.Year==y]
                if DFy.empty: continue
                #DATA
                breakpoint=BPdr[BPdr.Year>y]['S'].iloc[0]
                print(y,sp,dr,breakpoint)
                rcases=DFy[DFy[dr]>breakpoint].count()[dr]  
                N=len(DFy)
                R=rcases
                F=rcases/N
                #RECORD
                L.append([sp,dr,country,y,N,R,F])
#SAVE ALL IN DATAFRAME AND WRITE TO FILE
MICdf=pd.DataFrame.from_records(L, columns=['Species', 'Antibiotic', 'Country', 'Year', 'Number of cases', 'Number of resistant cases', 'Fraction of resistant cases'])
MICdf.to_csv('data/moving_breakpoints.csv', float_format='%.3f', na_rep='NaN', index=False)

# %%
#READ AVERAGE MIC DATA
DFavg=pd.read_csv('data/moving_breakpoints.csv')
#READ RESISTANCEMAP DATA
RD=pd.read_csv('data/resistmap_data.csv')
RD['year']=RD['year'].astype('int64')
RD['value']=RD['value'].astype('float64')
RD['IsolatesTested']=RD['IsolatesTested'].astype('float64')
spR=get_key(RD, 'Organism')
cR=get_key(RD, 'CountryName')
dR=get_key(RD, 'Antimicrobial')
#DATA IN RESISTANCEMAP IS AGGREGATED IN A SIMILAR WAY AS IN ECDC
Rant={}
Rant['Acinetobacter baumannii']={'Amikacin':['Amikacin'], 
    'Ampicillin-sulbactam':['Ampicillin sulbactam'],
    'Carbapenems':['Imipenem', 'Meropenem'],
    'Ceftazidime':['Ceftazidime'],
    'Glycylcyclines':['Tigecycline']}
Rant['Enterobacter aerogenes/cloacae']={'Amoxicillin-clavulanate':['Amoxicillin clavulanate'],
    'Carbapenems':['Imipenem', 'Meropenem'],
    'Glycylcyclines':['Tigecycline'],
    'Piperacillin-tazobactam':['Piperacillin tazobactam']}
Rant['Enterococcus faecalis']={'Aminoglycosides (high-level)':['Gentamicin'],
    'Vancomycin':['Vancomycin']}
Rant['Enterococcus faecium']={'Vancomycin':['Vancomycin']}
Rant['Escherichia coli']={'Amoxicillin-clavulanate':['Amoxicillin clavulanate'],
    'Carbapenems':['Imipenem', 'Meropenem'],
    'Glycylcyclines':['Tigecycline'],
    'Piperacillin-tazobactam':['Piperacillin tazobactam']}
Rant['Klebsiella pneumoniae']={'Amoxicillin-clavulanate':['Amoxicillin clavulanate'],
    'Carbapenems':['Imipenem, Meropenem'],
    'Glycylcyclines':['Tigecycline'],
    'Piperacillin-tazobactam':['Piperacillin tazobactam']}
Rant['Pseudomonas aeruginosa']={'Amikacin':['Amikacin'],
    'Carbapenems':['Imipenem', 'Meropenem'],
    'Ceftazidime':['Ceftazidime'],
    'Piperacillin-tazobactam':['Piperacillin tazobactam']}
Rant['Staphylococcus aureus']={'Linezolid':['Linezolid'],
    'Oxacillin (MRSA)':['Oxacillin'],
    'Vancomycin':['Vancomycin']}
Rant['Streptococcus pneumoniae']={'Macrolides':['Erythromycin', 'Clarithromycin', 'Azithromycin']}

#COMPARE RESISTANCE RATES
yL=list(range(2004,2018))
L=[]
for sp, country in itertools.product(spR, cR):
    DFsp=DFavg[(DFavg.Species==sp) & (DFavg.Country==country)]
    RDsp=RD[(RD.Organism==sp) & (RD.CountryName==country)]
    if DFsp.empty or RDsp.empty: continue
    for key,value in Rant[sp].items():
        DFc=DFsp[DFsp.Antibiotic.isin(value)]
        RDc=RDsp[RDsp.Antimicrobial==key]
        for y in yL:
            DFy=DFc[DFc.Year==y]
            RDy=RDc[RDc.year==y]
            if DFy.empty or RDy.empty: continue
            x1=RDy.value.mean()
            xhigh=RDy.CIHigh.mean()
            xlow=RDy.CILow.mean()
            if np.isnan(x1): continue
            y1=DFy['Fraction of resistant cases'].mean()*100
            diff=y1-x1
            N=DFy['Number of cases'].sum()
            L.append([sp,key,y,country,x1,xhigh,xlow,y1,diff,N])

NewDF=pd.DataFrame.from_records(L, columns=['Species','Antibiotic','Year','Country','RMapValue','RMapCIHigh', 'RMapCILow','ATLASValue','Diff','N'])
NewDF.to_excel('data/atlas_vs_resistancemap_moving_breakpoints.xls', float_format='%.3f', index=False)

# %%
#READ AVERAGE MIC DATA
DFavg=pd.read_csv('data/moving_breakpoints.csv')
#READ ECDC DATA
RD=pd.read_csv('data/europe_resistance_data.csv')
#we want to compare fraction of resistance in both datasets
RD=RD[RD.Indicator=='Nonsusceptible proportion']
RD['Year']=RD['Year'].astype('int64')
RD['Value']=RD['Value'].astype('float64')
spR=get_key(RD, 'Species')
cR=get_key(RD, 'Country')
dR=get_key(RD, 'Antibiotic')
#ECDC resistance data comes aggregated for drug classes and for different
#pathogens. For instance, for Acinetobacter it reports resistance to
#'Carbapenems'. We therefore compare with resistance to all drugs tested
#in ATLAS for that pathogen-drug class combination, as specified in the
#ECDC website.
#Also, Acinetobacter is reported as a genus, but we here only compare with
#A.baumannii, which is by far the most important pathogen
RD['Species']=RD['Species'].str.replace('Acinetobacter spp.', 'Acinetobacter baumannii')
Rant={}
Rant['Acinetobacter baumannii']={'Carbapenems':['Imipenem', 'Meropenem']}
Rant['Enterococcus faecalis']={'Highlevel gentamicin':['Gentamicin'],
    'Vancomycin':['Vancomycin']}
Rant['Enterococcus faecium']={'Highlevel gentamicin':['Gentamicin'],
    'Vancomycin':['Vancomycin']}
Rant['Escherichia coli']={'Carbapenems':['Imipenem', 'Meropenem']}
Rant['Klebsiella pneumoniae']={'Carbapenems':['Imipenem, Meropenem']}
Rant['Pseudomonas aeruginosa']={'Carbapenems':['Imipenem', 'Meropenem'],
    'Ceftazidime':['Ceftazidime'],
    'PiperacillinTazobactam':['Piperacillin tazobactam']}
Rant['Staphylococcus aureus']={'Meticillin (MRSA)':['Oxacillin']}
Rant['Streptococcus pneumoniae']={'Macrolides':['Erythromycin', 'Clarithromycin', 'Azithromycin'],
    'Penicillins': ['Penicillin', 'Oxacillin']}

#COMPARE RESISTANCE RATES
yL=list(range(2004,2018))
L=[]
for sp, country in itertools.product(spR, cR):
    DFsp=DFavg[(DFavg.Species==sp) & (DFavg.Country==country)]
    RDsp=RD[(RD.Species==sp) & (RD.Country==country)]
    if DFsp.empty or RDsp.empty: continue
    for key,value in Rant[sp].items():
        DFc=DFsp[DFsp.Antibiotic.isin(value)]
        RDc=RDsp[RDsp.Antibiotic==key]
        for y in yL:
            DFy=DFc[DFc.Year==y]
            RDy=RDc[RDc.Year==y]
            if DFy.empty or RDy.empty: continue
            x1=RDy.Value.mean()
            if np.isnan(x1): continue
            y1=DFy['Fraction of resistant cases'].mean()*100
            diff=y1-x1
            N=DFy['Number of cases'].sum()
            L.append([sp,key,y,country,x1,y1,diff,N])
NewDF=pd.DataFrame.from_records(L, columns=['Species','Antibiotic','Year','Country','ECDCValue','ATLASValue','Diff','N'])
NewDF.to_excel('data/atlas_vs_ecdc_moving_breakpoints.xls', float_format='%.3f', index=False)

# %% [markdown]
# # DIFFERENCES BETWEEN TEST AND INFORM
#
# Data for Fig 8D

# %%
#FIRST COMPARE RESISTANCE FRACTIONS
T=pd.read_csv('data/average_mic_per_year_test.csv')
I=pd.read_csv('data/average_mic_per_year_inform.csv')
Y=range(2012,2018)

L=[]
for index,row in T.iterrows():
    sp=row['Species']
    dr=row['Antibiotic']
    c=row['Country']
    y=row['Year']
    Iy=I[(I.Species==sp) & (I.Antibiotic==dr) & (I.Country==c) & (I.Year==y)]
    if Iy.empty: continue
    rT=row['Fraction of resistant cases']
    rI=Iy['Fraction of resistant cases'].mean()
    nT=row['Number of cases']
    nI=Iy['Number of resistant cases'].mean()
    diff=rT-rI
    L.append([sp,dr,y,c,rT*100,rI*100,diff*100,nT,nI])
NewDF=pd.DataFrame.from_records(L, columns=['Species','Antibiotic','Year','Country','TESTValue','INFORMValue','Diff','NTEST', 'NINFORM'])
NewDF.to_excel('data/test_vs_inform.xls', float_format='%.3f', index=False)

# %% [markdown]
# # CLINICAL PA PAIRS WITH LOW TAU
#
# Data for Supp Fig 22

# %%
DFM=pd.read_csv('results/Rcluster/resistant_cluster_trends_noBP.csv')
DFM=DFM[DFM.Breakpoint==True]
C=pd.read_csv('results/correlations/tau_test.csv')
TL=[]
for i,sp in enumerate(SPL):
    DFsp=DFM[DFM.Species==sp]
    for dr in drugs:
        DF=DFsp[DFsp.Antibiotic==dr]
        if DF.empty: continue
        Csp=C[(C.Species==sp) & (C.Antibiotic==dr)]
        t=Csp['Tau'].mean()
        TL.append([sp,dr,t])
DFT=pd.DataFrame.from_records(TL, columns=['Species', 'Antibiotic', 'Tau'])
DFT.to_csv('results/correlations/tau_fig4.csv', float_format='%.3f', index=False)
